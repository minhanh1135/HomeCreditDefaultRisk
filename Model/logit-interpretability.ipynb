# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/home-credit-default-risk/sample_submission.csv
# /kaggle/input/home-credit-default-risk/bureau_balance.csv
# /kaggle/input/home-credit-default-risk/POS_CASH_balance.csv
# /kaggle/input/home-credit-default-risk/application_train.csv
# /kaggle/input/home-credit-default-risk/HomeCredit_columns_description.csv
# /kaggle/input/home-credit-default-risk/application_test.csv
# /kaggle/input/home-credit-default-risk/previous_application.csv
# /kaggle/input/home-credit-default-risk/credit_card_balance.csv
# /kaggle/input/home-credit-default-risk/installments_payments.csv
# /kaggle/input/home-credit-default-risk/bureau.csv
# /kaggle/input/data-aggregation-ipynb/create_feature_train_ver2.pkl
# /kaggle/input/data-aggregation-ipynb/create_feature_test_kaggle_ver2.pkl
# /kaggle/input/data-aggregation-ipynb/__results__.html
# /kaggle/input/data-aggregation-ipynb/__notebook__.ipynb
# /kaggle/input/data-aggregation-ipynb/__output__.json
# /kaggle/input/data-aggregation-ipynb/custom.css

# %% [markdown]
# # Libs

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, roc_auc_score, confusion_matrix
import copy
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Load data

# %%
train_full = pd.read_pickle('/kaggle/input/data-aggregation-ipynb/create_feature_train_ver2.pkl')

temp, test = train_test_split(train_full, test_size = 0.15)
train, valid = train_test_split(temp, test_size = 0.2)
train.shape, valid.shape, test.shape
# Out:
# ((209107, 534), (52277, 534), (46127, 534))

# %%
train_full.isnull().sum().sum()
# Out:
# 54364313

# %%
test_kaggle = pd.read_pickle('/kaggle/input/data-aggregation-ipynb/create_feature_test_kaggle_ver2.pkl')
test_kaggle.shape
# Out:
# (48744, 533)

# %%
test_kaggle.isnull().sum().sum()
# Out:
# 7784556

# %% [markdown]
# # Funcs

# %%
def iv_woe(data, target, bins=10, show_woe=False):
    
    #Empty Dataframe
    newDF,woeDF = pd.DataFrame(), pd.DataFrame()
    
    #Extract Column Names
    cols = data.columns
    
    #Run WOE and IV on all the independent variables
    for ivars in cols[~cols.isin([target])]:
        try:
#     for ivars in ['CARD_M3CARD_IS_DPD_UNDER_120_MEAN']:
            if (data[ivars].dtype.kind in 'bifc') and (len(np.unique(data[ivars]))>10):
                binned_x = pd.qcut(data[ivars], bins,  duplicates='drop')
                d0 = pd.DataFrame({'x': binned_x, 'y': data[target]})
            else:
                d0 = pd.DataFrame({'x': data[ivars], 'y': data[target]})

            # missing
            if d0.isnull().sum().sum() > 0 :
                try:
                    d0['x'] = d0['x'].cat.add_categories('Missing')
                    d0['x'].fillna('Missing', inplace =True)
                except:
    #                 print('var ', ivars)
                    d0['x'].fillna('Missing', inplace =True)


            # Calculate the number of events in each group (bin)
            d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
            d.columns = ['Cutoff', 'N', 'Events']

            # Calculate % of events in each group.
            d['% of Events'] = np.maximum(d['Events'], 0.5) / d['Events'].sum()

            # Calculate the non events in each group.
            d['Non-Events'] = d['N'] - d['Events']
            # Calculate % of non events in each group.
            d['% of Non-Events'] = np.maximum(d['Non-Events'], 0.5) / d['Non-Events'].sum()

            # Calculate WOE by taking natural log of division of % of non-events and % of events
            d['WoE'] = np.log(d['% of Events']/d['% of Non-Events']) ## ln(good/bad) => event : good
            d['IV'] = d['WoE'] * (d['% of Events'] - d['% of Non-Events'])
            d.insert(loc=0, column='Variable', value=ivars)
    #         print("Information value of " + ivars + " is " + str(round(d['IV'].sum(),6)))
            temp =pd.DataFrame({"Variable" : [ivars], "IV" : [d['IV'].sum()]}, columns = ["Variable", "IV"])
            newDF=pd.concat([newDF,temp], axis=0)
            woeDF=pd.concat([woeDF,d], axis=0)
        
        except:
            print('Fail ', ivars)

        #Show WOE Table
        if show_woe == True:
            print(d)
    return newDF, woeDF

# %%
train[['PREV_PREV_CREDIT_APPL_RATIO_MAX', 'PREV_PREV_INTERESTS_RATE_MEAN', 'PREV_D365_PREV_INTERESTS_RATE_MEAN']]
# Out:
#         PREV_PREV_CREDIT_APPL_RATIO_MAX  PREV_PREV_INTERESTS_RATE_MEAN  \
# 40022                          1.000000                       0.005326
# 182441                         1.198000                            NaN
# 183176                              NaN                            NaN
# 304480                              inf                            NaN
# 298525                         1.110329                       0.030384
# ...                                 ...                            ...
# 267366                         1.126878                       0.008731
# 159110                         1.138600                       0.019819
# 264768                         1.105603                       0.008247
# 122424                              inf                           -inf
# 100106                         1.277202                            NaN
#
#         PREV_D365_PREV_INTERESTS_RATE_MEAN
# 40022                                  NaN
# 182441                                 NaN
# 183176                                 NaN
# 304480                                 NaN
# 298525                                 NaN
# ...                                    ...
# 267366                            0.003383
# 159110                            0.011544
# 264768                            0.008247
# 122424                                 NaN
# 100106                                -inf
#
# [209107 rows x 3 columns]

# %%
train[['PREV_PREV_CREDIT_APPL_RATIO_MAX',
       'PREV_PREV_INTERESTS_RATE_MEAN', 
       'PREV_D365_PREV_INTERESTS_RATE_MEAN']] = train[['PREV_PREV_CREDIT_APPL_RATIO_MAX',
                                                       'PREV_PREV_INTERESTS_RATE_MEAN', 
                                                       'PREV_D365_PREV_INTERESTS_RATE_MEAN']].replace([np.inf], 99999)

train[['PREV_PREV_CREDIT_APPL_RATIO_MAX', 
       'PREV_PREV_INTERESTS_RATE_MEAN', 
       'PREV_D365_PREV_INTERESTS_RATE_MEAN']] = train[['PREV_PREV_CREDIT_APPL_RATIO_MAX', 
                                                       'PREV_PREV_INTERESTS_RATE_MEAN', 
                                                       'PREV_D365_PREV_INTERESTS_RATE_MEAN']].replace([-np.inf], -99999)


test_kaggle[['PREV_PREV_CREDIT_APPL_RATIO_MAX',
       'PREV_PREV_INTERESTS_RATE_MEAN', 
       'PREV_D365_PREV_INTERESTS_RATE_MEAN']] = test_kaggle[['PREV_PREV_CREDIT_APPL_RATIO_MAX',
                                                       'PREV_PREV_INTERESTS_RATE_MEAN', 
                                                       'PREV_D365_PREV_INTERESTS_RATE_MEAN']].replace([np.inf], 99999)

test_kaggle[['PREV_PREV_CREDIT_APPL_RATIO_MAX', 
       'PREV_PREV_INTERESTS_RATE_MEAN', 
       'PREV_D365_PREV_INTERESTS_RATE_MEAN']] = test_kaggle[['PREV_PREV_CREDIT_APPL_RATIO_MAX', 
                                                       'PREV_PREV_INTERESTS_RATE_MEAN', 
                                                       'PREV_D365_PREV_INTERESTS_RATE_MEAN']].replace([-np.inf], -99999)

# %%
train[['PREV_PREV_CREDIT_APPL_RATIO_MAX', 'PREV_PREV_INTERESTS_RATE_MEAN', 'PREV_D365_PREV_INTERESTS_RATE_MEAN']]
# Out:
#         PREV_PREV_CREDIT_APPL_RATIO_MAX  PREV_PREV_INTERESTS_RATE_MEAN  \
# 40022                          1.000000                       0.005326
# 182441                         1.198000                            NaN
# 183176                              NaN                            NaN
# 304480                     99999.000000                            NaN
# 298525                         1.110329                       0.030384
# ...                                 ...                            ...
# 267366                         1.126878                       0.008731
# 159110                         1.138600                       0.019819
# 264768                         1.105603                       0.008247
# 122424                     99999.000000                  -99999.000000
# 100106                         1.277202                            NaN
#
#         PREV_D365_PREV_INTERESTS_RATE_MEAN
# 40022                                  NaN
# 182441                                 NaN
# 183176                                 NaN
# 304480                                 NaN
# 298525                                 NaN
# ...                                    ...
# 267366                            0.003383
# 159110                            0.011544
# 264768                            0.008247
# 122424                                 NaN
# 100106                       -99999.000000
#
# [209107 rows x 3 columns]

# %%
newDF, woeDF = iv_woe(data = train.drop(columns = ['SK_ID_CURR']),
                        target = 'TARGET')

# %%
newDF
# Out:
#                              Variable        IV
# 0                  NAME_CONTRACT_TYPE  0.014715
# 0                         CODE_GENDER  0.036156
# 0                        FLAG_OWN_CAR  0.007192
# 0                     FLAG_OWN_REALTY  0.000601
# 0                        CNT_CHILDREN  0.002109
# ..                                ...       ...
# 0              CARD_M3CARD_IS_DPD_SUM  0.005044
# 0   CARD_M3CARD_IS_DPD_UNDER_120_MEAN  0.006024
# 0    CARD_M3CARD_IS_DPD_UNDER_120_SUM  0.005895
# 0    CARD_M3CARD_IS_DPD_OVER_120_MEAN  0.002407
# 0     CARD_M3CARD_IS_DPD_OVER_120_SUM  0.002327
#
# [532 rows x 2 columns]

# %%
newDF[newDF['IV']>= 0.02]
# Out:
#                                 Variable        IV
# 0                            CODE_GENDER  0.036156
# 0                             AMT_CREDIT  0.044138
# 0                            AMT_ANNUITY  0.026306
# 0                        AMT_GOODS_PRICE  0.092142
# 0                       NAME_INCOME_TYPE  0.058087
# ..                                   ...       ...
# 0       CARD_M3CNT_DRAWINGS_CURRENT_MEAN  0.028359
# 0        CARD_M3CNT_DRAWINGS_CURRENT_SUM  0.027365
# 0   CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN  0.021785
# 0         CARD_M3BALANCE_LIMIT_RATIO_MIN  0.062942
# 0         CARD_M3BALANCE_LIMIT_RATIO_MAX  0.081338
#
# [228 rows x 2 columns]

# %%
woeDF
# Out:
#                            Variable   Cutoff       N   Events  % of Events  \
# 0                NAME_CONTRACT_TYPE        0  189228  15749.0     0.935214
# 1                NAME_CONTRACT_TYPE        1   19879   1091.0     0.064786
# 0                       CODE_GENDER        0   71490   7184.0     0.426603
# 1                       CODE_GENDER        1  137614   9656.0     0.573397
# 2                       CODE_GENDER        2       3      0.0     0.000030
# ..                              ...      ...     ...      ...          ...
# 0   CARD_M3CARD_IS_DPD_OVER_120_SUM      0.0   57553   4969.0     0.295071
# 1   CARD_M3CARD_IS_DPD_OVER_120_SUM      1.0     134      9.0     0.000534
# 2   CARD_M3CARD_IS_DPD_OVER_120_SUM      2.0     177     12.0     0.000713
# 3   CARD_M3CARD_IS_DPD_OVER_120_SUM      3.0     108      9.0     0.000534
# 4   CARD_M3CARD_IS_DPD_OVER_120_SUM  Missing  151135  11841.0     0.703147
#
#     Non-Events  % of Non-Events       WoE            IV
# 0     173479.0         0.902282  0.035848  1.180559e-03
# 1      18788.0         0.097718 -0.410996  1.353493e-02
# 0      64306.0         0.334462  0.243331  2.242089e-02
# 1     127958.0         0.665522 -0.148995  1.372624e-02
# 2          3.0         0.000016  0.643369  9.063718e-06
# ..         ...              ...       ...           ...
# 0      52584.0         0.273495  0.075935  1.638413e-03
# 1        125.0         0.000650 -0.195961  2.267187e-05
# 2        165.0         0.000858 -0.185911  2.706722e-05
# 3         99.0         0.000515  0.037233  7.272617e-07
# 4     139294.0         0.724482 -0.029891  6.377131e-04
#
# [3937 rows x 9 columns]

# %%
# chon bien co IV >= 0.02
woeDF[woeDF['Variable'].isin(newDF[newDF['IV']>= 0.02]['Variable'])]
# Out:
#                           Variable                 Cutoff       N   Events  \
# 0                      CODE_GENDER                      0   71490   7184.0
# 1                      CODE_GENDER                      1  137614   9656.0
# 2                      CODE_GENDER                      2       3      0.0
# 0                       AMT_CREDIT  (44999.999, 180000.0]   22514   1502.0
# 1                       AMT_CREDIT   (180000.0, 254700.0]   21544   1652.0
# ..                             ...                    ...     ...      ...
# 1   CARD_M3BALANCE_LIMIT_RATIO_MAX         (0.466, 0.891]    4466    349.0
# 2   CARD_M3BALANCE_LIMIT_RATIO_MAX         (0.891, 0.989]    4467    531.0
# 3   CARD_M3BALANCE_LIMIT_RATIO_MAX         (0.989, 1.035]    4466    716.0
# 4   CARD_M3BALANCE_LIMIT_RATIO_MAX           (1.035, inf]    4467    945.0
# 5   CARD_M3BALANCE_LIMIT_RATIO_MAX                Missing  164441  12771.0
#
#     % of Events  Non-Events  % of Non-Events       WoE        IV
# 0      0.426603     64306.0         0.334462  0.243331  0.022421
# 1      0.573397    127958.0         0.665522 -0.148995  0.013726
# 2      0.000030         3.0         0.000016  0.643369  0.000009
# 0      0.089192     21012.0         0.109286 -0.203168  0.004082
# 1      0.098100     19892.0         0.103460 -0.053203  0.000285
# ..          ...         ...              ...       ...       ...
# 1      0.020724      4117.0         0.021413 -0.032680  0.000022
# 2      0.031532      3936.0         0.020472  0.431970  0.004778
# 3      0.042518      3750.0         0.019504  0.779297  0.017934
# 4      0.056116      3522.0         0.018318  1.119529  0.042316
# 5      0.758373    151670.0         0.788851 -0.039402  0.001201
#
# [1961 rows x 9 columns]

# %%
transform_woe_df = woeDF[woeDF['Variable'].isin(newDF[newDF['IV']>= 0.02]['Variable'])]
transform_woe_df.shape
# Out:
# (1961, 9)

# %%
transform_woe_df.head()
# Out:
#       Variable                 Cutoff       N  Events  % of Events  \
# 0  CODE_GENDER                      0   71490  7184.0     0.426603
# 1  CODE_GENDER                      1  137614  9656.0     0.573397
# 2  CODE_GENDER                      2       3     0.0     0.000030
# 0   AMT_CREDIT  (44999.999, 180000.0]   22514  1502.0     0.089192
# 1   AMT_CREDIT   (180000.0, 254700.0]   21544  1652.0     0.098100
#
#    Non-Events  % of Non-Events       WoE        IV
# 0     64306.0         0.334462  0.243331  0.022421
# 1    127958.0         0.665522 -0.148995  0.013726
# 2         3.0         0.000016  0.643369  0.000009
# 0     21012.0         0.109286 -0.203168  0.004082
# 1     19892.0         0.103460 -0.053203  0.000285

# %%
final_list = list(transform_woe_df['Variable'].unique())
print(len(final_list))
keep_cols = final_list + ['TARGET']
print(len(keep_cols))
# Out:
# 228
# 229

# %%
map_transform_dict = {}
for idx in range(transform_woe_df.shape[0]):
    var = transform_woe_df.iloc[idx]['Variable']
    cutoff = transform_woe_df.iloc[idx]['Cutoff']
    woe = float(transform_woe_df.iloc[idx]['WoE'])
    
    if var not in map_transform_dict:
        map_transform_dict[var] = [[], []]  ## cutoff, woe
    if str(cutoff) == 'Missing':
        map_transform_dict[var][0].append('Missing')
    elif '(' not in str(cutoff):
        map_transform_dict[var][0].append(cutoff)
    elif '(' in str(cutoff):
        cutoff_str = str(cutoff).replace('(', '').replace(']', '')
        upper = cutoff_str.split(',')[0]
        lower = cutoff_str.split(',')[-1]
        map_transform_dict[var][0].append([upper, lower])
    map_transform_dict[var][1].append(woe)

# %%
from tqdm import tqdm
def map_woe_values(data, map_transform_dict):
    data = data.reset_index().drop(columns = ['index'])
    data_copy = copy.deepcopy(data)
    
    for var in tqdm(map_transform_dict.keys()):
#     for var in ['AMT_CREDIT', 'APPROVED_NEWX2_FLAG_AMT_CREDIT_RATIO_MIN']:
        try:
            cutoff_lst, woe_lst = map_transform_dict[var]
            for idx in range(len(cutoff_lst)):
                cutoff = cutoff_lst[idx]
                woe = woe_lst[idx]
                if type(cutoff) == int:
                    data[var] = data[var].replace({cutoff: woe})

                elif type(cutoff) == str:
                    if str(cutoff) != 'Missing':
                        data[var] = data[var].replace({cutoff: woe})
                    elif str(cutoff) == 'Missing':
                        data[var] = data[var].fillna(woe)
                elif type(cutoff) == float:
                    data[var] = data[var].map({cutoff: woe})

                elif len(cutoff) == 1:
                    if str(cutoff) != 'Missing':
                        data[var] = data[var].map({cutoff: woe})

                elif len(cutoff) == 2:
                    upper = float(cutoff[0])
                    lower = float(cutoff[-1])
                    index_ = data_copy[(data_copy[var]> upper)&
                                       (data_copy[var]<= lower)].index
                    data.iloc[index_, data.columns.get_loc(var)] = woe
        except:
            print('FAIL ', var)
                
    return data, data_copy

# %%
train_w = train[keep_cols].reset_index().drop(columns = ['index'])
train_temp = copy.deepcopy(train_w)
train_map, train_copy = map_woe_values(data = train_temp, map_transform_dict = map_transform_dict)
train_map.head()
# Out:
# 100%|██████████| 228/228 [00:26<00:00,  8.60it/s]
#    CODE_GENDER  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  NAME_INCOME_TYPE  \
# 0    -0.148995   -0.440929    -0.054495        -0.535892          0.186927
# 1     0.243331   -0.053203     0.039243         0.087040          0.186927
# 2    -0.148995   -0.138356     0.125151         0.042709         -0.073939
# 3    -0.148995   -0.440929    -0.353997        -0.535892         -0.073939
# 4     0.243331    0.280263     0.039243        -0.248066          0.186927
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  REGION_POPULATION_RELATIVE  \
# 0            -0.426814            0.043388                   -0.046570
# 1             0.109468            0.230408                   -0.144287
# 2            -0.426814            0.215902                   -0.605957
# 3             0.109468           -0.076393                    0.064697
# 4             0.109468           -0.076393                    0.013718
#
#    DAYS_BIRTH  DAYS_EMPLOYED  ...  CARD_M3AMT_TOTAL_RECEIVABLE_MEAN  \
# 0    0.224276      -0.336344  ...                         -0.029891
# 1   -0.154163       0.190582  ...                         -0.217207
# 2    0.103000       0.023608  ...                         -0.029891
# 3    0.103000       0.279253  ...                         -0.217207
# 4   -0.265192      -0.131730  ...                         -0.029891
#
#    CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX  CARD_M3CNT_DRAWINGS_ATM_CURRENT_SUM  \
# 0                            -0.065527                            -0.029891
# 1                            -0.065527                            -0.014616
# 2                            -0.065527                            -0.029891
# 3                             0.126867                            -0.014616
# 4                            -0.065527                            -0.029891
#
#    CARD_M3CNT_DRAWINGS_CURRENT_MAX  CARD_M3CNT_DRAWINGS_CURRENT_MEAN  \
# 0                        -0.029891                         -0.029891
# 1                        -0.083794                         -0.095585
# 2                        -0.029891                         -0.029891
# 3                        -0.083794                         -0.095585
# 4                        -0.029891                         -0.029891
#
#    CARD_M3CNT_DRAWINGS_CURRENT_SUM  CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN  \
# 0                        -0.029891                             -0.065527
# 1                        -0.088569                             -0.065527
# 2                        -0.029891                             -0.065527
# 3                        -0.088569                              0.145638
# 4                        -0.029891                             -0.065527
#
#    CARD_M3BALANCE_LIMIT_RATIO_MIN  CARD_M3BALANCE_LIMIT_RATIO_MAX  TARGET
# 0                       -0.039402                       -0.039402     0.0
# 1                       -0.301292                       -0.370609     0.0
# 2                       -0.039402                       -0.039402     0.0
# 3                       -0.301292                       -0.370609     0.0
# 4                       -0.039402                       -0.039402     0.0
#
# [5 rows x 229 columns]

# %%
valid_w = valid[keep_cols].reset_index().drop(columns = ['index'])
valid_temp = copy.deepcopy(valid_w)
valid_map, valid_copy = map_woe_values(data = valid_temp, map_transform_dict = map_transform_dict)
valid_map.head()
# Out:
# 100%|██████████| 228/228 [00:08<00:00, 28.21it/s]
#    CODE_GENDER  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  NAME_INCOME_TYPE  \
# 0    -0.148995    0.054611     0.039243         0.042709          0.186927
# 1     0.243331   -0.150041     0.239540        -0.192022         -0.073939
# 2    -0.148995   -0.138356     0.239540        -0.192022          0.186927
# 3     0.243331    0.249411     0.039243         0.261809          0.186927
# 4    -0.148995   -0.203168    -0.152308        -0.110534          0.186927
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  REGION_POPULATION_RELATIVE  \
# 0            -0.426814            0.043388                    0.013718
# 1             0.109468           -0.076393                    0.184204
# 2             0.109468           -0.076393                    0.013718
# 3             0.109468           -0.076393                   -0.046570
# 4             0.109468            0.230408                   -0.144287
#
#    DAYS_BIRTH  DAYS_EMPLOYED  ...  CARD_M3AMT_TOTAL_RECEIVABLE_MEAN  \
# 0    0.347810       0.372594  ...                         -0.029891
# 1   -0.052945      -0.336344  ...                         -0.029891
# 2    0.103000       0.279253  ...                         -0.217207
# 3   -0.052945       0.023608  ...                          0.557441
# 4   -0.265192      -0.336344  ...                         -0.217207
#
#    CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX  CARD_M3CNT_DRAWINGS_ATM_CURRENT_SUM  \
# 0                            -0.065527                            -0.029891
# 1                            -0.065527                            -0.029891
# 2                             0.126867                            -0.014616
# 3                             0.897375                             0.791270
# 4                            -0.065527                            -0.014616
#
#    CARD_M3CNT_DRAWINGS_CURRENT_MAX  CARD_M3CNT_DRAWINGS_CURRENT_MEAN  \
# 0                        -0.029891                         -0.029891
# 1                        -0.029891                         -0.029891
# 2                        -0.083794                         -0.095585
# 3                         0.645000                          0.639811
# 4                        -0.083794                         -0.095585
#
#    CARD_M3CNT_DRAWINGS_CURRENT_SUM  CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN  \
# 0                        -0.029891                             -0.065527
# 1                        -0.029891                             -0.065527
# 2                        -0.088569                              0.145638
# 3                         0.644845                              0.555891
# 4                        -0.088569                             -0.065527
#
#    CARD_M3BALANCE_LIMIT_RATIO_MIN  CARD_M3BALANCE_LIMIT_RATIO_MAX  TARGET
# 0                       -0.039402                       -0.039402     0.0
# 1                       -0.039402                       -0.039402     1.0
# 2                       -0.301292                       -0.370609     1.0
# 3                        0.661537                        1.119529     0.0
# 4                       -0.301292                       -0.370609     0.0
#
# [5 rows x 229 columns]

# %%
test_w = test[keep_cols].reset_index().drop(columns = ['index'])
test_temp = copy.deepcopy(test_w)
test_map, test_copy = map_woe_values(data = test_temp, map_transform_dict = map_transform_dict)
test_map.head()
# Out:
# 100%|██████████| 228/228 [00:07<00:00, 31.21it/s]
#    CODE_GENDER  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  NAME_INCOME_TYPE  \
# 0    -0.148995   -0.203168    -0.152308        -0.110534          0.186927
# 1    -0.148995    0.054611    -0.353997         0.042709         -0.073939
# 2    -0.148995   -0.150041     0.239540        -0.535892         -0.373258
# 3    -0.148995   -0.138356     0.065583        -0.192022          0.186927
# 4    -0.148995    0.054611    -0.353997         0.042709         -0.433923
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  REGION_POPULATION_RELATIVE  \
# 0            -0.426814           -0.076393                    0.064697
# 1             0.032517           -0.076393                   -0.605957
# 2            -0.426814           -0.076393                   -0.009331
# 3            -0.426814           -0.346184                    0.013718
# 4             0.109468            0.215902                   -0.009331
#
#    DAYS_BIRTH  DAYS_EMPLOYED  ...  CARD_M3AMT_TOTAL_RECEIVABLE_MEAN  \
# 0    0.402118       0.190582  ...                         -0.029891
# 1    0.347810       0.190582  ...                         -0.217207
# 2    0.347810       0.190582  ...                         -0.029891
# 3   -0.052945       0.393778  ...                         -0.029891
# 4   -0.534407      -0.337003  ...                         -0.029891
#
#    CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX  CARD_M3CNT_DRAWINGS_ATM_CURRENT_SUM  \
# 0                            -0.065527                            -0.029891
# 1                            -0.065527                            -0.014616
# 2                            -0.065527                            -0.029891
# 3                            -0.065527                            -0.029891
# 4                            -0.065527                            -0.029891
#
#    CARD_M3CNT_DRAWINGS_CURRENT_MAX  CARD_M3CNT_DRAWINGS_CURRENT_MEAN  \
# 0                        -0.029891                         -0.029891
# 1                        -0.083794                         -0.095585
# 2                        -0.029891                         -0.029891
# 3                        -0.029891                         -0.029891
# 4                        -0.029891                         -0.029891
#
#    CARD_M3CNT_DRAWINGS_CURRENT_SUM  CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN  \
# 0                        -0.029891                             -0.065527
# 1                        -0.088569                             -0.065527
# 2                        -0.029891                             -0.065527
# 3                        -0.029891                             -0.065527
# 4                        -0.029891                             -0.065527
#
#    CARD_M3BALANCE_LIMIT_RATIO_MIN  CARD_M3BALANCE_LIMIT_RATIO_MAX  TARGET
# 0                       -0.039402                       -0.039402     0.0
# 1                       -0.301292                       -0.370609     0.0
# 2                       -0.039402                       -0.039402     0.0
# 3                       -0.039402                       -0.039402     0.0
# 4                       -0.039402                       -0.039402     0.0
#
# [5 rows x 229 columns]

# %%
test_kaggle_w = test_kaggle[final_list].reset_index().drop(columns = ['index'])
test_kaggle_w_temp = copy.deepcopy(test_kaggle_w)
test_kaggle_map, test_kaggle_copy = map_woe_values(data = test_kaggle_w_temp, map_transform_dict = map_transform_dict)
test_kaggle_map.head()
# Out:
# 100%|██████████| 228/228 [00:07<00:00, 28.61it/s]
#    CODE_GENDER  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  NAME_INCOME_TYPE  \
# 0    -0.148995    0.280263     0.102726         0.557223          0.186927
# 1     0.243331   -0.053203     0.053719        -0.110534          0.186927
# 2     0.243331    0.054611    -0.353997         0.042709          0.186927
# 3    -0.148995   -0.440929    -0.353997        -0.535892          0.186927
# 4     0.243331    0.054611     0.065583         0.042709          0.186927
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  REGION_POPULATION_RELATIVE  \
# 0            -0.426814           -0.076393                    0.184204
# 1             0.109468           -0.076393                   -0.144287
# 2            -0.426814           -0.076393                    0.184204
# 3             0.109468           -0.076393                   -0.086609
# 4             0.109468           -0.076393                   -0.046570
#
#    DAYS_BIRTH  DAYS_EMPLOYED  ...  CARD_M3AMT_TOTAL_RECEIVABLE_MAX  \
# 0   -0.265192       0.023608  ...                        -0.029891
# 1   -0.154163      -0.336344  ...                        -0.029891
# 2   -0.265192      -0.336344  ...                        -0.218008
# 3    0.103000       0.023608  ...                        -0.218008
# 4    0.224276       0.023608  ...                        -0.029891
#
#    CARD_M3AMT_TOTAL_RECEIVABLE_MEAN  CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX  \
# 0                         -0.029891                            -0.065527
# 1                         -0.029891                            -0.065527
# 2                         -0.217207                             0.126867
# 3                         -0.217207                             0.126867
# 4                         -0.029891                            -0.065527
#
#    CARD_M3CNT_DRAWINGS_ATM_CURRENT_SUM  CARD_M3CNT_DRAWINGS_CURRENT_MAX  \
# 0                            -0.029891                        -0.029891
# 1                            -0.029891                        -0.029891
# 2                            -0.014616                        -0.083794
# 3                            -0.014616                         0.645000
# 4                            -0.029891                        -0.029891
#
#    CARD_M3CNT_DRAWINGS_CURRENT_MEAN  CARD_M3CNT_DRAWINGS_CURRENT_SUM  \
# 0                         -0.029891                        -0.029891
# 1                         -0.029891                        -0.029891
# 2                         -0.095585                        -0.088569
# 3                          0.639811                         0.644845
# 4                         -0.029891                        -0.029891
#
#    CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN  CARD_M3BALANCE_LIMIT_RATIO_MIN  \
# 0                             -0.065527                       -0.039402
# 1                             -0.065527                       -0.039402
# 2                              0.145638                       -0.301292
# 3                              0.555891                       -0.301292
# 4                             -0.065527                       -0.039402
#
#    CARD_M3BALANCE_LIMIT_RATIO_MAX
# 0                       -0.039402
# 1                       -0.039402
# 2                       -0.370609
# 3                       -0.370609
# 4                       -0.039402
#
# [5 rows x 228 columns]

# %%
train_map.to_pickle('train_w_woe_trans.pkl')
valid_map.to_pickle('valid_w_woe_trans.pkl')
test_map.to_pickle('test_w_woe_trans.pkl')
test_kaggle_map.to_pickle('test_kaggle_woe_trans.pkl')

# %% [markdown]
# # Backward selection

# %%
import pandas as pd
import statsmodels.api as sm

# %%
train_map_w = train_map[np.isfinite(train_map).all(1)]
valid_map_w = valid_map[np.isfinite(valid_map).all(1)]
test_map_w  = test_map[np.isfinite(test_map).all(1)]

# %%
def backward_regression(X, y,
                           initial_list=[], 
                           threshold_in=0.01, 
                           threshold_out = 0.05, 
                           verbose=True):
    included=list(X.columns)
    while True:
        changed=False
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {} with p-value = {}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

included = backward_regression(train_map_w.drop(columns = ['TARGET']), train_map_w['TARGET'])
# Out:
# Drop INS_D365AMT_DIFF_MEAN with p-value = 0.9973979233976689
# Drop NONLIVINGAREA_MODE with p-value = 0.9944612384610534
# Drop INS_AMT_DIFF_MAX with p-value = 0.984788040710697
# Drop FLOORSMAX_MEDI with p-value = 0.9818791438745125
# Drop INS_AMT_PAYMENT_MAX with p-value = 0.9796147006235063
# Drop CARD_M3AMT_DRAWINGS_POS_CURRENT_SUM with p-value = 0.9788443873593817
# Drop INS_AMT_DIFF_SUM with p-value = 0.9701618179368469
# Drop LIVINGAREA_MEDI with p-value = 0.9634175144556834
# Drop ELEVATORS_MODE with p-value = 0.9598274636695321
# Drop HOUSETYPE_MODE with p-value = 0.9474085791895221
# Drop INS_D365AMT_DIFF_MAX with p-value = 0.9465305884607024
# Drop INS_D365AMT_DIFF_SUM with p-value = 0.9400800005977136
# Drop BUREAU_BUREAU_CREDIT_DEBT_DIFF_MAX with p-value = 0.9126141305821757
# Drop PREV_D365_CNT_PAYMENT_SUM with p-value = 0.9110745716925933
# Drop APARTMENTS_MEDI with p-value = 0.8914146871170072
# Drop INS_DAYS_ENTRY_PAYMENT_MEAN with p-value = 0.8908533976680945
# Drop YEARS_BEGINEXPLUATATION_MODE with p-value = 0.887964877270902
# Drop BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX with p-value = 0.8818095318177905
# Drop DAYS_EMPLOYED with p-value = 0.8815016468583567
# Drop APPS_CAR_EMPLOYED_RATIO with p-value = 0.8683538564178408
# Drop BUREAU_AMT_CREDIT_SUM_MEAN with p-value = 0.850982907043842
# Drop DAYS_REGISTRATION with p-value = 0.8433826563319669
# Drop BUREAU_BUREAU_CREDIT_FACT_DIFF_MEAN with p-value = 0.8286555947762322
# Drop NONLIVINGAREA_MEDI with p-value = 0.822999830098114
# Drop DAYS_LAST_PHONE_CHANGE with p-value = 0.8106591869850763
# Drop CARD_M3AMT_DRAWINGS_ATM_CURRENT_MAX with p-value = 0.804036092747372
# Drop CARD_M3AMT_PAYMENT_TOTAL_CURRENT_MAX with p-value = 0.8043954363791848
# Drop INS_AMT_DIFF_MEAN with p-value = 0.8035249860110023
# Drop BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MAX_y with p-value = 0.8033086677230598
# Drop BUREAU_BUREAU_CREDIT_ENDDATE_DIFF_MIN with p-value = 0.795246701341319
# Drop PREV_PREV_CREDIT_DIFF_MAX with p-value = 0.7772002726496114
# Drop BUREAU_ACT_DAYS_CREDIT_MEAN_x with p-value = 0.7632292175775882
# Drop CARD_AMT_BALANCE_MAX with p-value = 0.75893075613006
# Drop CARD_AMT_TOTAL_RECEIVABLE_MAX with p-value = 0.8827943268855554
# Drop BASEMENTAREA_MODE with p-value = 0.7447886343884449
# Drop BASEMENTAREA_MEDI with p-value = 0.7821901756196763
# Drop CARD_M3CNT_DRAWINGS_CURRENT_MEAN with p-value = 0.7307350267525925
# Drop BUREAU_ACT_BUREAU_CREDIT_DEBT_DIFF_MEAN_x with p-value = 0.7227933884274635
# Drop BUREAU_ACT_BUREAU_CREDIT_DEBT_DIFF_MAX_x with p-value = 0.8710336804187423
# Drop FLOORSMIN_MODE with p-value = 0.6907583587871559
# Drop BUREAU_ACT_BUREAU_CREDIT_DEBT_DIFF_MIN_x with p-value = 0.6843615670391041
# Drop NONLIVINGAREA_AVG with p-value = 0.6742515329498013
# Drop PREV_RATE_DOWN_PAYMENT_MEAN with p-value = 0.6601353544523668
# Drop CARD_M3BALANCE_LIMIT_RATIO_MIN with p-value = 0.6305920680349468
# Drop ELEVATORS_AVG with p-value = 0.6262773270024267
# Drop CARD_AMT_DRAWINGS_POS_CURRENT_MAX with p-value = 0.6195594285483583
# Drop BUREAU_ACT_DAYS_CREDIT_MAX_y with p-value = 0.5770576561618407
# Drop BASEMENTAREA_AVG with p-value = 0.5721560638421763
# Drop FLOORSMAX_MODE with p-value = 0.5711428479339704
# Drop BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_x with p-value = 0.5690831968318153
# Drop ENTRANCES_AVG with p-value = 0.5508497079900961
# Drop INS_D365AMT_PAYMENT_MEAN with p-value = 0.5514201112026753
# Drop CARD_M3AMT_PAYMENT_TOTAL_CURRENT_SUM with p-value = 0.5677165092052042
# Drop BUREAU_DAYS_CREDIT_MEAN with p-value = 0.5499175634201154
# Drop BUREAU_DAYS_CREDIT_MIN with p-value = 0.5630886577642709
# Drop PREV_DAYS_DECISION_MIN with p-value = 0.5428135661061387
# Drop INS_INS_IS_DPD_MEAN with p-value = 0.5259579392412383
# Drop BUREAU_BUREAU_CREDIT_DEBT_RATIO_MIN with p-value = 0.5247190259692057
# Drop BUREAU_BUREAU_ENDDATE_FACT_DIFF_MEAN with p-value = 0.5266370182412851
# Drop BUREAU_BUREAU_ENDDATE_FACT_DIFF_MAX with p-value = 0.6753926653819252
# Drop CARD_M3CNT_DRAWINGS_ATM_CURRENT_SUM with p-value = 0.5223758078495772
# Drop BUREAU_DAYS_CREDIT_ENDDATE_MIN with p-value = 0.5159489171705346
# Drop BUREAU_ACT_DAYS_CREDIT_MIN_x with p-value = 0.5089679890157437
# Drop INS_D365AMT_RATIO_MEAN with p-value = 0.4849395709738453
# Drop CARD_DRAWING_LIMIT_RATIO_MAX with p-value = 0.4804059763245939
# Drop PREV_D365_PREV_CREDIT_APPL_RATIO_MEAN with p-value = 0.47151590899813656
# Drop BUREAU_ACT_BUREAU_CREDIT_ENDDATE_DIFF_MEAN_y with p-value = 0.45369122074310464
# Drop LIVINGAREA_AVG with p-value = 0.4520215863100622
# Drop LIVINGAREA_MODE with p-value = 0.4439276692485755
# Drop APPS_CAR_BIRTH_RATIO with p-value = 0.42946158299216874
# Drop CARD_M3CNT_DRAWINGS_CURRENT_MAX with p-value = 0.42763547570746263
# Drop PREV_APPROVED_RATIO with p-value = 0.3973606978925316
# Drop BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MEAN_x with p-value = 0.3934641196448756
# Drop BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MAX_x with p-value = 0.43789367125744505
# Drop BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MAX_y with p-value = 0.38826965811648007
# Drop APARTMENTS_MODE with p-value = 0.38105296452196924
# Drop CARD_SK_ID_CURR_COUNT with p-value = 0.3801600261714958
# Drop BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MEAN_y with p-value = 0.3768654046597515
# Drop APARTMENTS_AVG with p-value = 0.3620574165809367
# Drop BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MEAN_x with p-value = 0.3606221060214546
# Drop INS_AMT_RATIO_MEAN with p-value = 0.34565640192616265
# Drop ENTRANCES_MODE with p-value = 0.30392304804603737
# Drop CARD_CNT_DRAWINGS_ATM_CURRENT_MAX with p-value = 0.29537724916434266
# Drop AMT_CREDIT with p-value = 0.28214952249720376
# Drop INS_DAYS_INSTALMENT_MEAN with p-value = 0.27535453744134714
# Drop POS_MONTHS_BALANCE_MEAN with p-value = 0.31283729618657635
# Drop CARD_CNT_DRAWINGS_CURRENT_MEAN with p-value = 0.29686515324550355
# Drop CARD_AMT_TOTAL_RECEIVABLE_MEAN with p-value = 0.26082149324380316
# Drop AMT_GOODS_PRICE with p-value = 0.2511825343708666
# Drop CARD_M3AMT_TOTAL_RECEIVABLE_MEAN with p-value = 0.24750410894608035
# Drop CARD_M3AMT_INST_MIN_REGULARITY_MAX with p-value = 0.2795622747003709
# Drop PREV_D365_CNT_PAYMENT_MEAN with p-value = 0.227803871655105
# Drop INS_D365INS_IS_DPD_SUM with p-value = 0.2215018998718763
# Drop INS_D365INS_IS_DPD_MEAN with p-value = 0.43865462931747123
# Drop INS_D365INS_IS_DPD_UNDER_120_SUM with p-value = 0.43845201092239483
# Drop BUREAU_ACT_AMT_CREDIT_SUM_DEBT_SUM_y with p-value = 0.19316934745382383
# Drop BUREAU_BAL_MONTHS_BALANCE_MIN with p-value = 0.1915719067074209
# Drop REGION_RATING_CLIENT with p-value = 0.18232087356799032
# Drop REG_CITY_NOT_WORK_CITY with p-value = 0.18156149613826392
# Drop YEARS_BEGINEXPLUATATION_AVG with p-value = 0.17999705762903495
# Drop BUREAU_DAYS_ENDDATE_FACT_MIN with p-value = 0.1798935834682046
# Drop BUREAU_BAL_MONTHS_BALANCE_MEAN with p-value = 0.16173040499288105
# Drop PREV_PREV_CREDIT_APPL_RATIO_MAX with p-value = 0.16251180453119107
# Drop BUREAU_BUREAU_CREDIT_DEBT_RATIO_MAX with p-value = 0.1537731718857788
# Drop BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x with p-value = 0.2193232968296365
# Drop INS_AMT_INSTALMENT_MAX with p-value = 0.1359051851685183
# Drop WALLSMATERIAL_MODE with p-value = 0.10920306060457399
# Drop FLOORSMAX_AVG with p-value = 0.2101749643934544
# Drop EMERGENCYSTATE_MODE with p-value = 0.09699353855901334
# Drop CARD_M3AMT_BALANCE_MAX with p-value = 0.08940887808725938
# Drop CARD_M3AMT_TOTAL_RECEIVABLE_MAX with p-value = 0.4448722566127479
# Drop INS_SK_DPD_MAX with p-value = 0.08335916776520287
# Drop BUREAU_ACT_DAYS_CREDIT_MEAN_y with p-value = 0.08174243834370998
# Drop BUREAU_DAYS_CREDIT_MAX with p-value = 0.09733606826783023
# Drop BUREAU_BUREAU_CREDIT_FACT_DIFF_MIN with p-value = 0.07812009734011453
# Drop BUREAU_ACT_DAYS_CREDIT_MAX_x with p-value = 0.07940881501847248
# Drop BUREAU_ACT_DAYS_CREDIT_ENDDATE_MAX_x with p-value = 0.08557528655108558
# Drop BUREAU_ACT_DAYS_CREDIT_ENDDATE_MEAN_x with p-value = 0.8358237888335989
# Drop CARD_AMT_DRAWINGS_CURRENT_SUM with p-value = 0.07327728411199069
# Drop CARD_AMT_DRAWINGS_CURRENT_MAX with p-value = 0.16883821330122367
# Drop CARD_AMT_INST_MIN_REGULARITY_MAX with p-value = 0.15973117856012153
# Drop TOTALAREA_MODE with p-value = 0.06097781511528829
# Drop REGION_POPULATION_RELATIVE with p-value = 0.052949853423013137
# Drop PREV_D365_PREV_INTERESTS_RATE_MEAN with p-value = 0.05025555697825437

# %%
len(included), included
# Out:
# (104,
#  ['CODE_GENDER',
#   'AMT_ANNUITY',
#   'NAME_INCOME_TYPE',
#   'NAME_EDUCATION_TYPE',
#   'NAME_FAMILY_STATUS',
#   'DAYS_BIRTH',
#   'DAYS_ID_PUBLISH',
#   'OWN_CAR_AGE',
#   'FLAG_EMP_PHONE',
#   'REGION_RATING_CLIENT_W_CITY',
#   'REG_CITY_NOT_LIVE_CITY',
#   'ORGANIZATION_TYPE',
#   'EXT_SOURCE_1',
#   'EXT_SOURCE_2',
#   'EXT_SOURCE_3',
#   'FLOORSMIN_AVG',
#   'YEARS_BEGINEXPLUATATION_MEDI',
#   'ELEVATORS_MEDI',
#   'ENTRANCES_MEDI',
#   'FLOORSMIN_MEDI',
#   'FLAG_DOCUMENT_3',
#   'APPS_EXT_SOURCE_MEAN',
#   'APPS_EXT_SOURCE_STD',
#   'APPS_ANNUITY_CREDIT_RATIO',
#   'APPS_GOODS_CREDIT_RATIO',
#   'APPS_EMPLOYED_BIRTH_RATIO',
#   'APPS_INCOME_EMPLOYED_RATIO',
#   'APPS_INCOME_BIRTH_RATIO',
#   'PREV_AMT_ANNUITY_MEAN',
#   'PREV_AMT_DOWN_PAYMENT_MEAN',
#   'PREV_AMT_DOWN_PAYMENT_MAX',
#   'PREV_AMT_DOWN_PAYMENT_SUM',
#   'PREV_RATE_DOWN_PAYMENT_MAX',
#   'PREV_DAYS_DECISION_MEAN',
#   'PREV_CNT_PAYMENT_MEAN',
#   'PREV_PREV_CREDIT_DIFF_MEAN',
#   'PREV_PREV_CREDIT_DIFF_SUM',
#   'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
#   'PREV_PREV_DAYS_LAST_DUE_DIFF_MEAN',
#   'PREV_PREV_INTERESTS_RATE_MEAN',
#   'PREV_PREV_INTERESTS_RATE_MAX',
#   'PREV_D365_PREV_CREDIT_DIFF_MEAN',
#   'PREV_D365_PREV_CREDIT_DIFF_SUM',
#   'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX',
#   'PREV_D365_PREV_INTERESTS_RATE_MAX',
#   'PREV_REFUSED_RATIO',
#   'BUREAU_DAYS_CREDIT_ENDDATE_MAX',
#   'BUREAU_DAYS_CREDIT_ENDDATE_MEAN',
#   'BUREAU_DAYS_ENDDATE_FACT_MAX',
#   'BUREAU_DAYS_ENDDATE_FACT_MEAN',
#   'BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN',
#   'BUREAU_AMT_CREDIT_SUM_MAX',
#   'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
#   'BUREAU_AMT_CREDIT_SUM_DEBT_MEAN',
#   'BUREAU_AMT_CREDIT_SUM_DEBT_SUM',
#   'BUREAU_BUREAU_ENDDATE_FACT_DIFF_MIN',
#   'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
#   'BUREAU_BUREAU_CREDIT_ENDDATE_DIFF_MAX',
#   'BUREAU_BUREAU_CREDIT_ENDDATE_DIFF_MEAN',
#   'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
#   'BUREAU_BUREAU_CREDIT_DEBT_DIFF_MIN',
#   'BUREAU_BUREAU_CREDIT_DEBT_DIFF_MEAN',
#   'BUREAU_BUREAU_IS_DPD_SUM',
#   'BUREAU_ACT_SK_ID_BUREAU_COUNT_x',
#   'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MAX_x',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x',
#   'BUREAU_ACT_SK_ID_BUREAU_COUNT_y',
#   'BUREAU_ACT_DAYS_CREDIT_ENDDATE_MAX_y',
#   'BUREAU_ACT_DAYS_CREDIT_ENDDATE_MEAN_y',
#   'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_y',
#   'BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MEAN_y',
#   'BUREAU_ACT_BUREAU_CREDIT_ENDDATE_DIFF_MIN_y',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_DIFF_MIN_y',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_DIFF_MAX_y',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_DIFF_MEAN_y',
#   'POS_SK_ID_CURR_COUNT',
#   'POS_MONTHS_BALANCE_MIN',
#   'POS_POS_IS_DPD_UNDER_120_MEAN',
#   'INS_DAYS_ENTRY_PAYMENT_SUM',
#   'INS_DAYS_INSTALMENT_SUM',
#   'INS_AMT_INSTALMENT_MEAN',
#   'INS_AMT_INSTALMENT_SUM',
#   'INS_AMT_PAYMENT_MEAN',
#   'INS_AMT_PAYMENT_SUM',
#   'INS_SK_DPD_MEAN',
#   'INS_INS_IS_DPD_SUM',
#   'INS_INS_IS_DPD_UNDER_120_MEAN',
#   'INS_INS_IS_DPD_UNDER_120_SUM',
#   'INS_D365SK_DPD_MEAN',
#   'INS_D365SK_DPD_MAX',
#   'INS_D365INS_IS_DPD_UNDER_120_MEAN',
#   'CARD_AMT_INST_MIN_REGULARITY_MEAN',
#   'CARD_CNT_DRAWINGS_ATM_CURRENT_SUM',
#   'CARD_CNT_DRAWINGS_CURRENT_MAX',
#   'CARD_CNT_DRAWINGS_CURRENT_SUM',
#   'CARD_CNT_DRAWINGS_POS_CURRENT_MEAN',
#   'CARD_BALANCE_LIMIT_RATIO_MIN',
#   'CARD_BALANCE_LIMIT_RATIO_MAX',
#   'CARD_M3AMT_INST_MIN_REGULARITY_MEAN',
#   'CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX',
#   'CARD_M3CNT_DRAWINGS_CURRENT_SUM',
#   'CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN',
#   'CARD_M3BALANCE_LIMIT_RATIO_MAX'])

# %%
import pandas as pd
import statsmodels.api as sm

def forward_regression(X, y,
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    initial_list = []
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
#         print('excluded ', len(excluded))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
#             print('new column ', new_column)
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add {} with p-value {}'.format(best_feature, best_pval))

        if not changed:
            break

    return included


included2 = forward_regression(train_map_w[included], train_map_w['TARGET'])
# Out:
# Add BUREAU_BUREAU_IS_DPD_SUM with p-value 0.0
# Add EXT_SOURCE_2 with p-value 0.0
# Add EXT_SOURCE_3 with p-value 0.0
# Add EXT_SOURCE_1 with p-value 2.4300827193109824e-210
# Add CARD_M3BALANCE_LIMIT_RATIO_MAX with p-value 3.351524758216374e-173
# Add APPS_GOODS_CREDIT_RATIO with p-value 2.4421569921706975e-146
# Add BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y with p-value 4.4379989550995056e-129
# Add INS_D365SK_DPD_MAX with p-value 3.728161509512486e-107
# Add APPS_EMPLOYED_BIRTH_RATIO with p-value 9.854069340400455e-97
# Add INS_AMT_PAYMENT_SUM with p-value 2.3386009490049986e-79
# Add PREV_REFUSED_RATIO with p-value 1.6686569010452646e-73
# Add PREV_PREV_DAYS_LAST_DUE_DIFF_MEAN with p-value 3.1443638641179876e-61
# Add APPS_ANNUITY_CREDIT_RATIO with p-value 1.7750166019228168e-56
# Add CODE_GENDER with p-value 5.980304771661944e-46
# Add PREV_PREV_CREDIT_APPL_RATIO_MEAN with p-value 8.026163650768329e-45
# Add FLAG_DOCUMENT_3 with p-value 3.980340754543835e-36
# Add NAME_EDUCATION_TYPE with p-value 1.5442829330644604e-32
# Add APPS_EXT_SOURCE_MEAN with p-value 4.489032669570771e-28
# Add PREV_PREV_INTERESTS_RATE_MEAN with p-value 1.6517913018581693e-24
# Add OWN_CAR_AGE with p-value 4.358314969001002e-22
# Add INS_INS_IS_DPD_UNDER_120_MEAN with p-value 6.016973651098223e-22
# Add PREV_D365_PREV_CREDIT_APPL_RATIO_MAX with p-value 2.657092302234459e-21
# Add INS_INS_IS_DPD_SUM with p-value 3.062999544377407e-19
# Add REG_CITY_NOT_LIVE_CITY with p-value 9.030055936240313e-17
# Add BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN with p-value 6.088175263006882e-14
# Add PREV_D365_PREV_INTERESTS_RATE_MAX with p-value 3.008282565306733e-12
# Add BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MEAN_y with p-value 1.932733831338766e-11
# Add BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN with p-value 1.3493297802533298e-14
# Add BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_y with p-value 3.859212777062855e-12
# Add CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX with p-value 1.169338337837147e-10
# Add APPS_INCOME_BIRTH_RATIO with p-value 4.869544867040682e-10
# Add BUREAU_AMT_CREDIT_SUM_MAX with p-value 1.0270464154490492e-08
# Add BUREAU_AMT_CREDIT_SUM_DEBT_MAX with p-value 1.4089535401743745e-12
# Add BUREAU_ACT_SK_ID_BUREAU_COUNT_y with p-value 2.4355520253893652e-09
# Add REGION_RATING_CLIENT_W_CITY with p-value 8.53183797326813e-08
# Add POS_SK_ID_CURR_COUNT with p-value 4.2624687291255266e-08
# Add PREV_AMT_DOWN_PAYMENT_MEAN with p-value 2.682017142375188e-07
# Add CARD_M3AMT_INST_MIN_REGULARITY_MEAN with p-value 5.229079022173295e-07
# Add INS_INS_IS_DPD_UNDER_120_SUM with p-value 7.725609400343727e-07
# Add AMT_ANNUITY with p-value 1.1447642496710104e-06
# Add BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x with p-value 2.4547703372443953e-06
# Add BUREAU_ACT_BUREAU_CREDIT_ENDDATE_DIFF_MIN_y with p-value 6.821115994511125e-07
# Add BUREAU_ACT_SK_ID_BUREAU_COUNT_x with p-value 3.595513539815759e-06
# Add BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX with p-value 8.59269907816506e-07
# Add NAME_FAMILY_STATUS with p-value 9.951817118601889e-06
# Add FLAG_EMP_PHONE with p-value 3.462707966144223e-06
# Add NAME_INCOME_TYPE with p-value 3.744565507852821e-12
# Add YEARS_BEGINEXPLUATATION_MEDI with p-value 5.451148702954079e-06
# Add APPS_INCOME_EMPLOYED_RATIO with p-value 6.774432482662881e-06
# Add CARD_CNT_DRAWINGS_CURRENT_MAX with p-value 1.4775489243965105e-05
# Add APPS_EXT_SOURCE_STD with p-value 2.3209614978783946e-05
# Add PREV_PREV_CREDIT_DIFF_MEAN with p-value 3.317154834569238e-05
# Add BUREAU_ACT_DAYS_CREDIT_ENDDATE_MAX_y with p-value 8.387143163472222e-05
# Add BUREAU_AMT_CREDIT_SUM_DEBT_SUM with p-value 0.00016743315514934284
# Add INS_D365INS_IS_DPD_UNDER_120_MEAN with p-value 0.0003428169054106194
# Add BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MAX_x with p-value 0.0005730813318780196
# Add PREV_AMT_ANNUITY_MEAN with p-value 0.0005320981263801123
# Add POS_POS_IS_DPD_UNDER_120_MEAN with p-value 0.00024474555041916087
# Add ORGANIZATION_TYPE with p-value 0.0008199988787817941
# Add INS_SK_DPD_MEAN with p-value 0.0007647726641280223
# Add PREV_D365_PREV_CREDIT_DIFF_SUM with p-value 0.0015488444505728205
# Add BUREAU_BUREAU_ENDDATE_FACT_DIFF_MIN with p-value 0.0016685892008338208
# Add PREV_PREV_CREDIT_DIFF_SUM with p-value 0.0018370497999949805
# Add DAYS_ID_PUBLISH with p-value 0.0020629221014017395
# Add INS_D365SK_DPD_MEAN with p-value 0.0023722660843443193
# Add DAYS_BIRTH with p-value 0.003205380265574174
# Add PREV_AMT_DOWN_PAYMENT_SUM with p-value 0.002954576088358905
# Add PREV_CNT_PAYMENT_MEAN with p-value 0.00015722998024649793
# Add PREV_AMT_DOWN_PAYMENT_MAX with p-value 0.0012273975323368335
# Add CARD_CNT_DRAWINGS_CURRENT_SUM with p-value 0.0023021079110789266
# Add CARD_CNT_DRAWINGS_ATM_CURRENT_SUM with p-value 0.0011905061212309966
# Add CARD_BALANCE_LIMIT_RATIO_MIN with p-value 0.00441645905439115
# Add INS_AMT_INSTALMENT_SUM with p-value 0.006409963011232732
# Add PREV_PREV_INTERESTS_RATE_MAX with p-value 0.00534076940793345
# Add PREV_RATE_DOWN_PAYMENT_MAX with p-value 0.005510550099979429

# %%
len(included2), included2
# Out:
# (75,
#  ['BUREAU_BUREAU_IS_DPD_SUM',
#   'EXT_SOURCE_2',
#   'EXT_SOURCE_3',
#   'EXT_SOURCE_1',
#   'CARD_M3BALANCE_LIMIT_RATIO_MAX',
#   'APPS_GOODS_CREDIT_RATIO',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
#   'INS_D365SK_DPD_MAX',
#   'APPS_EMPLOYED_BIRTH_RATIO',
#   'INS_AMT_PAYMENT_SUM',
#   'PREV_REFUSED_RATIO',
#   'PREV_PREV_DAYS_LAST_DUE_DIFF_MEAN',
#   'APPS_ANNUITY_CREDIT_RATIO',
#   'CODE_GENDER',
#   'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
#   'FLAG_DOCUMENT_3',
#   'NAME_EDUCATION_TYPE',
#   'APPS_EXT_SOURCE_MEAN',
#   'PREV_PREV_INTERESTS_RATE_MEAN',
#   'OWN_CAR_AGE',
#   'INS_INS_IS_DPD_UNDER_120_MEAN',
#   'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX',
#   'INS_INS_IS_DPD_SUM',
#   'REG_CITY_NOT_LIVE_CITY',
#   'BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN',
#   'PREV_D365_PREV_INTERESTS_RATE_MAX',
#   'BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MEAN_y',
#   'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
#   'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_y',
#   'CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX',
#   'APPS_INCOME_BIRTH_RATIO',
#   'BUREAU_AMT_CREDIT_SUM_MAX',
#   'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
#   'BUREAU_ACT_SK_ID_BUREAU_COUNT_y',
#   'REGION_RATING_CLIENT_W_CITY',
#   'POS_SK_ID_CURR_COUNT',
#   'PREV_AMT_DOWN_PAYMENT_MEAN',
#   'CARD_M3AMT_INST_MIN_REGULARITY_MEAN',
#   'INS_INS_IS_DPD_UNDER_120_SUM',
#   'AMT_ANNUITY',
#   'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x',
#   'BUREAU_ACT_BUREAU_CREDIT_ENDDATE_DIFF_MIN_y',
#   'BUREAU_ACT_SK_ID_BUREAU_COUNT_x',
#   'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
#   'NAME_FAMILY_STATUS',
#   'FLAG_EMP_PHONE',
#   'NAME_INCOME_TYPE',
#   'YEARS_BEGINEXPLUATATION_MEDI',
#   'APPS_INCOME_EMPLOYED_RATIO',
#   'CARD_CNT_DRAWINGS_CURRENT_MAX',
#   'APPS_EXT_SOURCE_STD',
#   'PREV_PREV_CREDIT_DIFF_MEAN',
#   'BUREAU_ACT_DAYS_CREDIT_ENDDATE_MAX_y',
#   'BUREAU_AMT_CREDIT_SUM_DEBT_SUM',
#   'INS_D365INS_IS_DPD_UNDER_120_MEAN',
#   'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MAX_x',
#   'PREV_AMT_ANNUITY_MEAN',
#   'POS_POS_IS_DPD_UNDER_120_MEAN',
#   'ORGANIZATION_TYPE',
#   'INS_SK_DPD_MEAN',
#   'PREV_D365_PREV_CREDIT_DIFF_SUM',
#   'BUREAU_BUREAU_ENDDATE_FACT_DIFF_MIN',
#   'PREV_PREV_CREDIT_DIFF_SUM',
#   'DAYS_ID_PUBLISH',
#   'INS_D365SK_DPD_MEAN',
#   'DAYS_BIRTH',
#   'PREV_AMT_DOWN_PAYMENT_SUM',
#   'PREV_CNT_PAYMENT_MEAN',
#   'PREV_AMT_DOWN_PAYMENT_MAX',
#   'CARD_CNT_DRAWINGS_CURRENT_SUM',
#   'CARD_CNT_DRAWINGS_ATM_CURRENT_SUM',
#   'CARD_BALANCE_LIMIT_RATIO_MIN',
#   'INS_AMT_INSTALMENT_SUM',
#   'PREV_PREV_INTERESTS_RATE_MAX',
#   'PREV_RATE_DOWN_PAYMENT_MAX'])

# %%
include1 = ['CODE_GENDER',
  'AMT_ANNUITY',
  'NAME_INCOME_TYPE',
  'NAME_EDUCATION_TYPE',
  'DAYS_BIRTH',
  'DAYS_EMPLOYED',
  'DAYS_ID_PUBLISH',
  'OWN_CAR_AGE',
  'FLAG_EMP_PHONE',
  'OCCUPATION_TYPE',
  'REGION_RATING_CLIENT',
  'REGION_RATING_CLIENT_W_CITY',
  'REG_CITY_NOT_LIVE_CITY',
  'ORGANIZATION_TYPE',
  'EXT_SOURCE_1',
  'EXT_SOURCE_2',
  'EXT_SOURCE_3',
  'ELEVATORS_MODE',
  'YEARS_BEGINEXPLUATATION_MEDI',
  'ENTRANCES_MEDI',
  'HOUSETYPE_MODE',
  'WALLSMATERIAL_MODE',
  'FLAG_DOCUMENT_3',
  'APPS_EXT_SOURCE_MEAN',
  'APPS_EXT_SOURCE_STD',
  'APPS_ANNUITY_CREDIT_RATIO',
  'APPS_GOODS_CREDIT_RATIO',
  'APPS_INCOME_EMPLOYED_RATIO',
  'APPS_INCOME_BIRTH_RATIO',
  'PREV_AMT_DOWN_PAYMENT_MEAN',
  'PREV_DAYS_DECISION_MEAN',
  'PREV_CNT_PAYMENT_MEAN',
  'PREV_PREV_CREDIT_DIFF_MEAN',
  'PREV_PREV_CREDIT_DIFF_SUM',
  'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
  'PREV_PREV_DAYS_LAST_DUE_DIFF_MEAN',
  'PREV_PREV_DAYS_LAST_DUE_DIFF_SUM',
  'PREV_PREV_INTERESTS_RATE_MEAN',
  'PREV_PREV_INTERESTS_RATE_MAX',
  'PREV_D365_CNT_PAYMENT_MEAN',
  'PREV_D365_PREV_CREDIT_DIFF_SUM',
  'PREV_D365_PREV_CREDIT_APPL_RATIO_MEAN',
  'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX',
  'PREV_D365_PREV_INTERESTS_RATE_MAX',
  'PREV_REFUSED_RATIO',
  'PREV_APPROVED_RATIO',
  'BUREAU_DAYS_CREDIT_MAX',
  'BUREAU_DAYS_CREDIT_ENDDATE_MAX',
  'BUREAU_DAYS_CREDIT_ENDDATE_MEAN',
  'BUREAU_DAYS_ENDDATE_FACT_MAX',
  'BUREAU_DAYS_ENDDATE_FACT_MEAN',
  'BUREAU_AMT_CREDIT_SUM_MAX',
  'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
  'BUREAU_AMT_CREDIT_SUM_DEBT_MEAN',
  'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
  'BUREAU_BUREAU_CREDIT_ENDDATE_DIFF_MAX',
  'BUREAU_BUREAU_CREDIT_ENDDATE_DIFF_MEAN',
  'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
  'BUREAU_BUREAU_CREDIT_DEBT_DIFF_MIN',
  'BUREAU_BUREAU_CREDIT_DEBT_DIFF_MEAN',
  'BUREAU_BUREAU_IS_DPD_SUM',
  'BUREAU_ACT_SK_ID_BUREAU_COUNT_x',
  'BUREAU_ACT_DAYS_CREDIT_MAX_x',
  'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MAX_x',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MEAN_x',
  'BUREAU_ACT_SK_ID_BUREAU_COUNT_y',
  'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_y',
  'BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MEAN_y',
  'BUREAU_ACT_AMT_CREDIT_SUM_DEBT_SUM_y',
  'BUREAU_ACT_BUREAU_CREDIT_ENDDATE_DIFF_MEAN_y',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
  'POS_SK_ID_CURR_COUNT',
  'POS_MONTHS_BALANCE_MIN',
  'INS_DAYS_ENTRY_PAYMENT_SUM',
  'INS_DAYS_INSTALMENT_SUM',
  'INS_AMT_INSTALMENT_MEAN',
  'INS_AMT_INSTALMENT_MAX',
  'INS_AMT_PAYMENT_MEAN',
  'INS_AMT_PAYMENT_SUM',
  'INS_SK_DPD_MEAN',
  'INS_INS_IS_DPD_SUM',
  'INS_INS_IS_DPD_UNDER_120_MEAN',
  'INS_INS_IS_DPD_UNDER_120_SUM',
  'INS_D365AMT_RATIO_MEAN',
  'INS_D365SK_DPD_MEAN',
  'INS_D365SK_DPD_MAX',
  'CARD_AMT_INST_MIN_REGULARITY_MEAN',
  'CARD_CNT_DRAWINGS_ATM_CURRENT_SUM',
  'CARD_CNT_DRAWINGS_CURRENT_MAX',
  'CARD_CNT_DRAWINGS_CURRENT_SUM',
  'CARD_CNT_DRAWINGS_POS_CURRENT_MEAN',
  'CARD_BALANCE_LIMIT_RATIO_MAX',
  'CARD_M3AMT_TOTAL_RECEIVABLE_MAX',
  'CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX',
  'CARD_M3CNT_DRAWINGS_CURRENT_SUM',
  'CARD_M3CNT_DRAWINGS_POS_CURRENT_MEAN',
  'CARD_M3BALANCE_LIMIT_RATIO_MAX']


include2 = ['APPS_EXT_SOURCE_MEAN',
  'BUREAU_BUREAU_IS_DPD_SUM',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
  'INS_D365SK_DPD_MAX',
  'APPS_GOODS_CREDIT_RATIO',
  'CARD_M3BALANCE_LIMIT_RATIO_MAX',
  'DAYS_EMPLOYED',
  'PREV_REFUSED_RATIO',
  'POS_SK_ID_CURR_COUNT',
  'NAME_EDUCATION_TYPE',
  'PREV_PREV_DAYS_LAST_DUE_DIFF_MEAN',
  'APPS_ANNUITY_CREDIT_RATIO',
  'CODE_GENDER',
  'FLAG_DOCUMENT_3',
  'BUREAU_AMT_CREDIT_SUM_MAX',
  'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX',
  'INS_INS_IS_DPD_UNDER_120_MEAN',
  'PREV_AMT_DOWN_PAYMENT_MEAN',
  'REG_CITY_NOT_LIVE_CITY',
  'OWN_CAR_AGE',
  'EXT_SOURCE_3',
  'EXT_SOURCE_2',
  'EXT_SOURCE_1',
  'PREV_PREV_INTERESTS_RATE_MEAN',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x',
  'PREV_PREV_DAYS_LAST_DUE_DIFF_SUM',
  'INS_AMT_PAYMENT_SUM',
  'PREV_D365_PREV_INTERESTS_RATE_MAX',
  'REGION_RATING_CLIENT_W_CITY',
  'APPS_INCOME_BIRTH_RATIO',
  'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
  'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
  'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MAX_x',
  'OCCUPATION_TYPE',
  'BUREAU_ACT_SK_ID_BUREAU_COUNT_y',
  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x',
  'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
  'DAYS_ID_PUBLISH',
  'DAYS_BIRTH',
  'NAME_INCOME_TYPE',
  'FLAG_EMP_PHONE',
  'ORGANIZATION_TYPE',
  'BUREAU_ACT_AMT_CREDIT_SUM_DEBT_MEAN_y',
  'BUREAU_ACT_BUREAU_CREDIT_ENDDATE_DIFF_MEAN_y',
  'PREV_PREV_CREDIT_DIFF_MEAN',
  'CARD_M3CNT_DRAWINGS_ATM_CURRENT_MAX',
  'INS_INS_IS_DPD_SUM',
  'PREV_PREV_INTERESTS_RATE_MAX',
  'WALLSMATERIAL_MODE',
  'APPS_INCOME_EMPLOYED_RATIO',
  'AMT_ANNUITY',
  'INS_AMT_INSTALMENT_MAX',
  'INS_D365AMT_RATIO_MEAN',
  'CARD_M3AMT_TOTAL_RECEIVABLE_MAX',
  'PREV_CNT_PAYMENT_MEAN',
  'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
  'APPS_EXT_SOURCE_STD',
  'BUREAU_ACT_SK_ID_BUREAU_COUNT_x',
  'PREV_D365_PREV_CREDIT_APPL_RATIO_MEAN',
  'BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_y',
  'PREV_D365_PREV_CREDIT_DIFF_SUM',
  'PREV_PREV_CREDIT_DIFF_SUM',
  'CARD_CNT_DRAWINGS_CURRENT_MAX',
  'INS_INS_IS_DPD_UNDER_120_SUM']

# %%
train_temp = pd.read_pickle('/kaggle/input/data-aggregation-ipynb/create_feature_train_ver2.pkl')

# %%
include_iv = include2 + ['TARGET']
newDF_include2, woeDF_include2 = iv_woe(data = train_temp[include_iv],
                        target = 'TARGET')
# Out:
# Fail  PREV_PREV_INTERESTS_RATE_MEAN

# %%
newDF_include2.sort_values(by = ['IV'], ascending = False).head(20)
# Out:
#                                     Variable        IV
# 0                       APPS_EXT_SOURCE_MEAN  0.608221
# 0                               EXT_SOURCE_3  0.329443
# 0                               EXT_SOURCE_2  0.306386
# 0                               EXT_SOURCE_1  0.150901
# 0       BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN  0.138003
# 0  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x  0.127823
# 0  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y  0.124962
# 0                              DAYS_EMPLOYED  0.101263
# 0                  APPS_ANNUITY_CREDIT_RATIO  0.093505
# 0                                 DAYS_BIRTH  0.084200
# 0             CARD_M3BALANCE_LIMIT_RATIO_MAX  0.081209
# 0                         INS_D365SK_DPD_MAX  0.080892
# 0                 APPS_INCOME_EMPLOYED_RATIO  0.075130
# 0                    APPS_GOODS_CREDIT_RATIO  0.072068
# 0                         PREV_REFUSED_RATIO  0.069108
# 0              INS_INS_IS_DPD_UNDER_120_MEAN  0.062390
# 0                           NAME_INCOME_TYPE  0.058381
# 0                     INS_D365AMT_RATIO_MEAN  0.055321
# 0          PREV_D365_PREV_INTERESTS_RATE_MAX  0.051542
# 0                REGION_RATING_CLIENT_W_CITY  0.051201

# %%
logit_vars = newDF_include2.sort_values(by = ['IV'], ascending = False).head(30)['Variable'].to_list()
logit_vars
# Out:
# ['APPS_EXT_SOURCE_MEAN',
#  'EXT_SOURCE_3',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_1',
#  'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
#  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x',
#  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
#  'DAYS_EMPLOYED',
#  'APPS_ANNUITY_CREDIT_RATIO',
#  'DAYS_BIRTH',
#  'CARD_M3BALANCE_LIMIT_RATIO_MAX',
#  'INS_D365SK_DPD_MAX',
#  'APPS_INCOME_EMPLOYED_RATIO',
#  'APPS_GOODS_CREDIT_RATIO',
#  'PREV_REFUSED_RATIO',
#  'INS_INS_IS_DPD_UNDER_120_MEAN',
#  'NAME_INCOME_TYPE',
#  'INS_D365AMT_RATIO_MEAN',
#  'PREV_D365_PREV_INTERESTS_RATE_MAX',
#  'REGION_RATING_CLIENT_W_CITY',
#  'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
#  'NAME_EDUCATION_TYPE',
#  'CARD_CNT_DRAWINGS_CURRENT_MAX',
#  'CARD_M3AMT_TOTAL_RECEIVABLE_MAX',
#  'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
#  'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
#  'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX',
#  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x',
#  'PREV_PREV_INTERESTS_RATE_MAX',
#  'CODE_GENDER']

# %%
logit_var_logic_trend = ['APPS_EXT_SOURCE_MEAN',
 'EXT_SOURCE_3',
 'EXT_SOURCE_2',
 'EXT_SOURCE_1',
 'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
 'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x',
 'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
 'DAYS_BIRTH',
 'CARD_M3BALANCE_LIMIT_RATIO_MAX',
 'INS_D365SK_DPD_MAX',
 'APPS_INCOME_EMPLOYED_RATIO',
 'APPS_GOODS_CREDIT_RATIO',
 'PREV_REFUSED_RATIO',
 'INS_INS_IS_DPD_UNDER_120_MEAN',
 'INS_D365AMT_RATIO_MEAN',
 'REGION_RATING_CLIENT_W_CITY',
 'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
 'NAME_EDUCATION_TYPE',
 'CARD_CNT_DRAWINGS_CURRENT_MAX',
 'CARD_M3AMT_TOTAL_RECEIVABLE_MAX',
 'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
 'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
 'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX']

# %%
log_reg_sm = LogisticRegression(C = 0.0001)

# Train on the training data
log_reg_sm.fit(train_map_w[logit_var_logic_trend], train_map_w['TARGET'])
# Out:
# LogisticRegression(C=0.0001)

# %%
import matplotlib.pyplot as plt

def plot_roc_curve(true_y, y_prob):
    """
    plots the roc curve based of the probabilities
    """
    (true_y_test, true_y_valid, true_y_train) = true_y
    (y_prob_test, y_prob_valid, y_prob_train) = y_prob
    fpr_test, tpr_test, thresholds = roc_curve(true_y_test, y_prob_test)
    fpr_valid, tpr_valid, thresholds = roc_curve(true_y_valid, y_prob_valid)
    fpr_train, tpr_train, thresholds = roc_curve(true_y_train, y_prob_train)
    
    gini_test = 2 * roc_auc_score(true_y_test, y_prob_test) - 1
    gini_valid = 2 * roc_auc_score(true_y_valid, y_prob_valid) - 1
    gini_train = 2 * roc_auc_score(true_y_train, y_prob_train) - 1
    
    plt.plot(fpr_test, tpr_test, label = 'Test = {}'.format(np.round(gini_test, 4)))
    plt.plot(fpr_valid, tpr_valid, label = 'Valid = {}'.format(np.round(gini_valid, 4)))
    plt.plot(fpr_train, tpr_train, label = 'Train = {}'.format(np.round(gini_train, 4)))
    plt.plot([0, 1], [0, 1], '--', color = 'blue')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc=1)
    

pred_test = log_reg_sm.predict_proba(test_map_w[logit_var_logic_trend])[:, 1]
pred_valid = log_reg_sm.predict_proba(valid_map_w[logit_var_logic_trend])[:, 1]
pred_train = log_reg_sm.predict_proba(train_map_w[logit_var_logic_trend])[:, 1]

plot_roc_curve(true_y = (test_map_w['TARGET'], valid_map_w['TARGET'], train_map_w['TARGET']), 
               y_prob = (pred_test, pred_valid, pred_train))

# %%
log_reg_sm.coef_
# Out:
# array([[0.34641004, 0.20388702, 0.17646604, 0.10349585, 0.09665826,
#         0.0956286 , 0.09149855, 0.06121557, 0.07004004, 0.08041867,
#         0.07161726, 0.08135689, 0.06587767, 0.06647768, 0.00036285,
#         0.0370322 , 0.05635652, 0.05235768, 0.03988822, 0.03579684,
#         0.02074229, 0.0345053 , 0.04935554]])

# %%
idx_lst = [num for num in log_reg_sm.coef_[0] if num < 0]
idx_lst
# Out:
# []

# %%
log_reg_sm.intercept_
# Out:
# array([-2.3671241])

# %% [markdown]
# # Intepretability

# %%
logit_vars
# Out:
# ['APPS_EXT_SOURCE_MEAN',
#  'EXT_SOURCE_3',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_1',
#  'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN',
#  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x',
#  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y',
#  'DAYS_EMPLOYED',
#  'APPS_ANNUITY_CREDIT_RATIO',
#  'DAYS_BIRTH',
#  'CARD_M3BALANCE_LIMIT_RATIO_MAX',
#  'INS_D365SK_DPD_MAX',
#  'APPS_INCOME_EMPLOYED_RATIO',
#  'APPS_GOODS_CREDIT_RATIO',
#  'PREV_REFUSED_RATIO',
#  'INS_INS_IS_DPD_UNDER_120_MEAN',
#  'NAME_INCOME_TYPE',
#  'INS_D365AMT_RATIO_MEAN',
#  'PREV_D365_PREV_INTERESTS_RATE_MAX',
#  'REGION_RATING_CLIENT_W_CITY',
#  'PREV_PREV_CREDIT_APPL_RATIO_MEAN',
#  'NAME_EDUCATION_TYPE',
#  'CARD_CNT_DRAWINGS_CURRENT_MAX',
#  'CARD_M3AMT_TOTAL_RECEIVABLE_MAX',
#  'BUREAU_AMT_CREDIT_SUM_DEBT_MAX',
#  'BUREAU_BUREAU_CREDIT_FACT_DIFF_MAX',
#  'PREV_D365_PREV_CREDIT_APPL_RATIO_MAX',
#  'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MIN_x',
#  'PREV_PREV_INTERESTS_RATE_MAX',
#  'CODE_GENDER']

# %%
newDF_include2, woeDF_include2
# Out:
# (                                     Variable        IV
#  0                        APPS_EXT_SOURCE_MEAN  0.608221
#  0                    BUREAU_BUREAU_IS_DPD_SUM  0.024747
#  0   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y  0.124962
#  0                          INS_D365SK_DPD_MAX  0.080892
#  0                     APPS_GOODS_CREDIT_RATIO  0.072068
#  ..                                        ...       ...
#  0    BUREAU_ACT_AMT_CREDIT_MAX_OVERDUE_MEAN_y  0.021715
#  0              PREV_D365_PREV_CREDIT_DIFF_SUM  0.023125
#  0                   PREV_PREV_CREDIT_DIFF_SUM  0.033978
#  0               CARD_CNT_DRAWINGS_CURRENT_MAX  0.048945
#  0                INS_INS_IS_DPD_UNDER_120_SUM  0.030603
#
#  [63 rows x 2 columns],
#                          Variable                Cutoff      N  Events  \
#  0           APPS_EXT_SOURCE_MEAN  (-0.00099404, 0.304]  30786  7057.0
#  1           APPS_EXT_SOURCE_MEAN        (0.304, 0.384]  30731  4455.0
#  2           APPS_EXT_SOURCE_MEAN        (0.384, 0.439]  30740  3233.0
#  3           APPS_EXT_SOURCE_MEAN        (0.439, 0.484]  30680  2486.0
#  4           APPS_EXT_SOURCE_MEAN        (0.484, 0.524]  30839  1986.0
#  ..                           ...                   ...    ...     ...
#  2   INS_INS_IS_DPD_UNDER_120_SUM            (2.0, 3.0]  15702  1503.0
#  3   INS_INS_IS_DPD_UNDER_120_SUM            (3.0, 5.0]  22256  2170.0
#  4   INS_INS_IS_DPD_UNDER_120_SUM           (5.0, 10.0]  30127  3017.0
#  5   INS_INS_IS_DPD_UNDER_120_SUM         (10.0, 134.0]  27773  2689.0
#  6   INS_INS_IS_DPD_UNDER_120_SUM               Missing  15868   949.0
#
#      % of Events  Non-Events  % of Non-Events       WoE        IV
#  0      0.284270     23729.0         0.083941  1.219808  0.244362
#  1      0.179456     26276.0         0.092951  0.657857  0.056908
#  2      0.130232     27507.0         0.097306  0.291456  0.009596
#  3      0.100141     28194.0         0.099736  0.004051  0.000002
#  4      0.080000     28853.0         0.102067 -0.243606  0.005376
#  ..          ...         ...              ...       ...       ...
#  2      0.060544     14199.0         0.050229  0.186777  0.001927
#  3      0.087412     20086.0         0.071054  0.207190  0.003389
#  4      0.121531     27110.0         0.095901  0.236846  0.006070
#  5      0.108318     25084.0         0.088734  0.199425  0.003905
#  6      0.038228     14919.0         0.052776 -0.322497  0.004692
#
#  [528 rows x 9 columns])

# %% [markdown]
# ## APPS_EXT_SOURCE_MEAN

# %%
woeDF_include2[woeDF_include2['Variable'] == 'APPS_EXT_SOURCE_MEAN']
# Out:
#                 Variable                Cutoff      N  Events  % of Events  \
# 0   APPS_EXT_SOURCE_MEAN  (-0.00099404, 0.304]  30786  7057.0     0.284270
# 1   APPS_EXT_SOURCE_MEAN        (0.304, 0.384]  30731  4455.0     0.179456
# 2   APPS_EXT_SOURCE_MEAN        (0.384, 0.439]  30740  3233.0     0.130232
# 3   APPS_EXT_SOURCE_MEAN        (0.439, 0.484]  30680  2486.0     0.100141
# 4   APPS_EXT_SOURCE_MEAN        (0.484, 0.524]  30839  1986.0     0.080000
# 5   APPS_EXT_SOURCE_MEAN        (0.524, 0.563]  30651  1646.0     0.066304
# 6   APPS_EXT_SOURCE_MEAN        (0.563, 0.603]  30879  1280.0     0.051561
# 7   APPS_EXT_SOURCE_MEAN        (0.603, 0.644]  30792  1149.0     0.046284
# 8   APPS_EXT_SOURCE_MEAN        (0.644, 0.692]  30551   893.0     0.035972
# 9   APPS_EXT_SOURCE_MEAN        (0.692, 0.879]  30690   626.0     0.025217
# 10  APPS_EXT_SOURCE_MEAN               Missing    172    14.0     0.000564
#
#     Non-Events  % of Non-Events       WoE            IV
# 0      23729.0         0.083941  1.219808  2.443625e-01
# 1      26276.0         0.092951  0.657857  5.690789e-02
# 2      27507.0         0.097306  0.291456  9.596399e-03
# 3      28194.0         0.099736  0.004051  1.640320e-06
# 4      28853.0         0.102067 -0.243606  5.375727e-03
# 5      29005.0         0.102605 -0.436635  1.585022e-02
# 6      29599.0         0.104706 -0.708395  3.764790e-02
# 7      29643.0         0.104862 -0.817848  4.790788e-02
# 8      29658.0         0.104915 -1.070415  7.379783e-02
# 9      30064.0         0.106351 -1.439248  1.167729e-01
# 10       158.0         0.000559  0.008948  4.495029e-08

# %%
temp = woeDF_include2[woeDF_include2['Variable'] == 'APPS_EXT_SOURCE_MEAN']
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()
# 10 la missing : chi co 115 obs => nhom vao nhom cuoi cung
# # NEW_EXTSOURCE_MEAN cang lon thi khach hang cang bad

# %% [markdown]
# ## EXT_SOURCE_3

# %%
woeDF_include2[woeDF_include2['Variable'] == 'EXT_SOURCE_3']
# Out:
#         Variable              Cutoff      N  Events  % of Events  Non-Events  \
# 0   EXT_SOURCE_3  (-0.000473, 0.228]  24701  4941.0     0.199033     19760.0
# 1   EXT_SOURCE_3       (0.228, 0.33]  24744  3156.0     0.127130     21588.0
# 2   EXT_SOURCE_3       (0.33, 0.408]  25057  2383.0     0.095992     22674.0
# 3   EXT_SOURCE_3      (0.408, 0.476]  24689  1970.0     0.079355     22719.0
# 4   EXT_SOURCE_3      (0.476, 0.535]  24186  1494.0     0.060181     22692.0
# 5   EXT_SOURCE_3      (0.535, 0.592]  25392  1357.0     0.054663     24035.0
# 6   EXT_SOURCE_3      (0.592, 0.643]  24725  1173.0     0.047251     23552.0
# 7   EXT_SOURCE_3      (0.643, 0.694]  24745  1043.0     0.042014     23702.0
# 8   EXT_SOURCE_3      (0.694, 0.749]  23675   836.0     0.033676     22839.0
# 9   EXT_SOURCE_3      (0.749, 0.896]  24632   795.0     0.032024     23837.0
# 10  EXT_SOURCE_3             Missing  60965  5677.0     0.228681     55288.0
#
#     % of Non-Events       WoE        IV
# 0          0.069901  1.046394  0.135123
# 1          0.076367  0.509653  0.025871
# 2          0.080209  0.179627  0.002835
# 3          0.080368 -0.012683  0.000013
# 4          0.080273 -0.288070  0.005788
# 5          0.085024 -0.441749  0.013412
# 6          0.083315 -0.567161  0.020454
# 7          0.083846 -0.690973  0.028904
# 8          0.080793 -0.875111  0.041233
# 9          0.084323 -0.968167  0.050634
# 10         0.195581  0.156353  0.005175

# %%
temp = woeDF_include2[woeDF_include2['Variable'] == 'EXT_SOURCE_3']
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()
# Missing la tot

# %% [markdown]
# ## EXT_SOURCE_2

# %%
temp3 = woeDF_include2[woeDF_include2['Variable'] == 'EXT_SOURCE_2']
temp3
# Out:
#         Variable                  Cutoff      N  Events  % of Events  \
# 0   EXT_SOURCE_2  (-0.0009999404, 0.216]  30694  5631.0     0.226828
# 1   EXT_SOURCE_2           (0.216, 0.34]  30710  3711.0     0.149486
# 2   EXT_SOURCE_2            (0.34, 0.44]  30681  3054.0     0.123021
# 3   EXT_SOURCE_2           (0.44, 0.512]  30787  2571.0     0.103565
# 4   EXT_SOURCE_2          (0.512, 0.566]  30696  2279.0     0.091803
# 5   EXT_SOURCE_2          (0.566, 0.608]  30760  2044.0     0.082336
# 6   EXT_SOURCE_2          (0.608, 0.646]  30754  1798.0     0.072427
# 7   EXT_SOURCE_2          (0.646, 0.682]  30679  1493.0     0.060141
# 8   EXT_SOURCE_2          (0.682, 0.722]  30656  1290.0     0.051964
# 9   EXT_SOURCE_2          (0.722, 0.855]  30434   902.0     0.036334
# 10  EXT_SOURCE_2                 Missing    660    52.0     0.002095
#
#     Non-Events  % of Non-Events       WoE        IV
# 0      25063.0         0.088660  0.939380  0.129792
# 1      26999.0         0.095509  0.447987  0.024181
# 2      27627.0         0.097730  0.230144  0.005821
# 3      28216.0         0.099814  0.036891  0.000138
# 4      28417.0         0.100525 -0.090765  0.000792
# 5      28716.0         0.101583 -0.210060  0.004043
# 6      28956.0         0.102432 -0.346617  0.010400
# 7      29186.0         0.103245 -0.540416  0.023294
# 8      29366.0         0.103882 -0.692710  0.035964
# 9      29532.0         0.104469 -1.056130  0.071959
# 10       608.0         0.002151 -0.026446  0.000001

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## EXT_SOURCE_1

# %%
temp = woeDF_include2[woeDF_include2['Variable'] == 'EXT_SOURCE_1']
temp
# Out:
#         Variable                         Cutoff       N   Events  % of Events  \
# 0   EXT_SOURCE_1  (0.013600000000000001, 0.213]   13425   2358.0     0.094985
# 1   EXT_SOURCE_1                 (0.213, 0.296]   13403   1553.0     0.062558
# 2   EXT_SOURCE_1                 (0.296, 0.369]   13469   1220.0     0.049144
# 3   EXT_SOURCE_1                 (0.369, 0.438]   13366   1124.0     0.045277
# 4   EXT_SOURCE_1                 (0.438, 0.506]   13421    899.0     0.036213
# 5   EXT_SOURCE_1                 (0.506, 0.573]   13460    808.0     0.032548
# 6   EXT_SOURCE_1                 (0.573, 0.641]   13439    693.0     0.027915
# 7   EXT_SOURCE_1                  (0.641, 0.71]   13349    585.0     0.023565
# 8   EXT_SOURCE_1                  (0.71, 0.787]   13416    470.0     0.018933
# 9   EXT_SOURCE_1                 (0.787, 0.963]   13385    344.0     0.013857
# 10  EXT_SOURCE_1                        Missing  173378  14771.0     0.595005
#
#     Non-Events  % of Non-Events       WoE        IV
# 0      11067.0         0.039149  0.886332  0.049489
# 1      11850.0         0.041919  0.400346  0.008263
# 2      12249.0         0.043331  0.125892  0.000732
# 3      12242.0         0.043306  0.044507  0.000088
# 4      12522.0         0.044296 -0.201474  0.001629
# 5      12652.0         0.044756 -0.318523  0.003889
# 6      12746.0         0.045089 -0.479457  0.008234
# 7      12764.0         0.045153 -0.650287  0.014038
# 8      12946.0         0.045796 -0.883324  0.023729
# 9      13041.0         0.046132 -1.202726  0.038819
# 10    158607.0         0.561071  0.058722  0.001993

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN

# %%
temp = woeDF_include2[woeDF_include2['Variable'] == 'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN']
temp
# Out:
#                                Variable           Cutoff      N  Events  \
# 0  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN      (-inf, 0.0]  69538  3854.0
# 1  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN    (0.0, 0.0375]   5904   252.0
# 2  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN  (0.0375, 0.125]  25147  1199.0
# 3  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN   (0.125, 0.189]  25148  1442.0
# 4  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN   (0.189, 0.252]  25147  1699.0
# 5  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN    (0.252, 0.33]  25147  2062.0
# 6  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN     (0.33, 0.44]  25147  2454.0
# 7  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN    (0.44, 0.617]  25147  2974.0
# 8  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN     (0.617, inf]  25148  3485.0
# 9  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN          Missing  56038  5404.0
#
#    % of Events  Non-Events  % of Non-Events       WoE        IV
# 0     0.155247     65684.0         0.232357 -0.403258  0.031095
# 1     0.010151      5652.0         0.019994 -0.677850  0.006672
# 2     0.048298     23948.0         0.084716 -0.561911  0.020464
# 3     0.058087     23706.0         0.083860 -0.367212  0.009464
# 4     0.068439     23448.0         0.082947 -0.192260  0.002789
# 5     0.083061     23085.0         0.081663  0.016979  0.000024
# 6     0.098852     22693.0         0.080276  0.208148  0.003866
# 7     0.119799     22173.0         0.078437  0.423518  0.017517
# 8     0.140383     21663.0         0.076633  0.605348  0.038591
# 9     0.217684     50634.0         0.179117  0.195002  0.007520

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %%
temp = woeDF[woeDF['Variable'] == 'BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN']
temp['Bin']= [i for i in range(temp.shape[0])] 
temp.loc[9, 'Bin'] = -1
temp = temp.sort_values(by = ['Bin'])
temp = temp.reset_index().drop(columns = ['index'])
temp['Bin'] = [i for i in range(temp.shape[0])] 
temp
# Out:
#                                Variable           Cutoff      N  Events  \
# 0  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN          Missing  38012  3654.0
# 1  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN      (-inf, 0.0]  47343  2652.0
# 2  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN    (0.0, 0.0368]   3986   184.0
# 3  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN  (0.0368, 0.125]  17109   806.0
# 4  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN   (0.125, 0.189]  17110   946.0
# 5  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN   (0.189, 0.253]  17109  1160.0
# 6  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN    (0.253, 0.33]  17109  1439.0
# 7  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN     (0.33, 0.44]  17110  1621.0
# 8  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN    (0.44, 0.619]  17109  1998.0
# 9  BUREAU_BUREAU_CREDIT_DEBT_RATIO_MEAN     (0.619, inf]  17110  2380.0
#
#    % of Events  Non-Events  % of Non-Events       WoE        IV  Bin
# 0     0.216983     34358.0         0.178699  0.194116  0.007432    0
# 1     0.157482     44691.0         0.232442 -0.389330  0.029184    1
# 2     0.010926      3802.0         0.019775 -0.593219  0.005249    2
# 3     0.047862     16303.0         0.084794 -0.571893  0.021121    3
# 4     0.056176     16164.0         0.084071 -0.403171  0.011246    4
# 5     0.068884     15949.0         0.082952 -0.185848  0.002615    5
# 6     0.085451     15670.0         0.081501  0.047328  0.000187    6
# 7     0.096259     15489.0         0.080560  0.178041  0.002795    7
# 8     0.118646     15111.0         0.078594  0.411852  0.016496    8
# 9     0.141330     14730.0         0.076612  0.612342  0.039630    9

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()
## Cut off tai diem 0

# %% [markdown]
# ## BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x

# %%
temp = woeDF_include2[woeDF_include2['Variable'] == 'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x']
temp
# Out:
#                                      Variable           Cutoff       N  \
# 0   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (-inf, 0.0124]   20328
# 1   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x  (0.0124, 0.429]   20327
# 2   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.429, 0.653]   20328
# 3   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.653, 0.786]   20329
# 4   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.786, 0.867]   20326
# 5   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.867, 0.922]   20327
# 6   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.922, 0.956]   20327
# 7   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.956, 0.988]   20336
# 8   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x   (0.988, 1.003]   20325
# 9   BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x     (1.003, inf]   20322
# 10  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_x          Missing  104236
#
#     Events  % of Events  Non-Events  % of Non-Events       WoE        IV
# 0   1028.0     0.041410     19300.0         0.068274 -0.500004  0.013432
# 1   1002.0     0.040363     19325.0         0.068362 -0.526916  0.014753
# 2   1021.0     0.041128     19307.0         0.068298 -0.507200  0.013781
# 3   1160.0     0.046727     19169.0         0.067810 -0.372389  0.007851
# 4   1372.0     0.055267     18954.0         0.067050 -0.193260  0.002277
# 5   1555.0     0.062638     18772.0         0.066406 -0.058405  0.000220
# 6   1920.0     0.077341     18407.0         0.065115  0.172080  0.002104
# 7   2204.0     0.088781     18132.0         0.064142  0.325081  0.008010
# 8   2289.0     0.092205     18036.0         0.063802  0.368231  0.010459
# 9   3242.0     0.130594     17080.0         0.060420  0.770768  0.054088
# 10  8032.0     0.323545     96204.0         0.340321 -0.050552  0.000848

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y

# %%
# BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y
temp = woeDF_include2[woeDF_include2['Variable'] == 'BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y']
temp
# Out:
#                                     Variable          Cutoff       N  Events  \
# 0  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y     (-inf, 0.0]   41470  2186.0
# 1  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y    (0.0, 0.467]   18162   981.0
# 2  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y  (0.467, 0.702]   19877  1112.0
# 3  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y   (0.702, 0.82]   19878  1306.0
# 4  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y    (0.82, 0.89]   19877  1499.0
# 5  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y   (0.89, 0.937]   19877  1743.0
# 6  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y  (0.937, 0.972]   19877  2197.0
# 7  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y    (0.972, 1.0]   24528  2829.0
# 8  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y      (1.0, inf]   15227  2663.0
# 9  BUREAU_ACT_BUREAU_CREDIT_DEBT_RATIO_MAX_y         Missing  108738  8309.0
#
#    % of Events  Non-Events  % of Non-Events       WoE        IV
# 0     0.088056     39284.0         0.138967 -0.456258  0.023228
# 1     0.039517     17181.0         0.060778 -0.430501  0.009153
# 2     0.044794     18765.0         0.066381 -0.393348  0.008491
# 3     0.052608     18572.0         0.065698 -0.222201  0.002909
# 4     0.060383     18378.0         0.065012 -0.073871  0.000342
# 5     0.070211     18134.0         0.064149  0.090305  0.000547
# 6     0.088499     17680.0         0.062543  0.347144  0.009011
# 7     0.113958     21699.0         0.076760  0.395143  0.014698
# 8     0.107271     12564.0         0.044445  0.881103  0.055356
# 9     0.334703    100429.0         0.355267 -0.059626  0.001226

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## DAYS_EMPLOYED

# %%
# DAYS_EMPLOYED
temp = woeDF_include2[woeDF_include2['Variable'] == 'DAYS_EMPLOYED']
temp
# Out:
#         Variable                 Cutoff      N  Events  % of Events  \
# 0  DAYS_EMPLOYED  (-17912.001, -4881.0]  30754  1464.0     0.058973
# 1  DAYS_EMPLOYED     (-4881.0, -3231.0]  30762  1843.0     0.074240
# 2  DAYS_EMPLOYED     (-3231.0, -2362.0]  30766  2211.0     0.089063
# 3  DAYS_EMPLOYED     (-2362.0, -1695.0]  30740  2546.0     0.102558
# 4  DAYS_EMPLOYED     (-1695.0, -1213.0]  30800  2972.0     0.119718
# 5  DAYS_EMPLOYED      (-1213.0, -822.0]  30690  3219.0     0.129668
# 6  DAYS_EMPLOYED       (-822.0, -458.0]  30771  3475.0     0.139980
# 7  DAYS_EMPLOYED       (-458.0, -144.0]  30803  3475.0     0.139980
# 8  DAYS_EMPLOYED     (-144.0, 365243.0]  61425  3620.0     0.145821
#
#    Non-Events  % of Non-Events       WoE        IV
# 0     29290.0         0.103613 -0.563588  0.025159
# 1     28919.0         0.102301 -0.320619  0.008997
# 2     28555.0         0.101013 -0.125902  0.001504
# 3     28194.0         0.099736  0.027900  0.000079
# 4     27828.0         0.098441  0.195678  0.004163
# 5     27471.0         0.097178  0.288425  0.009371
# 6     27296.0         0.096559  0.371340  0.016124
# 7     27328.0         0.096673  0.370168  0.016031
# 8     57805.0         0.204485 -0.338116  0.019835

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## APPS_ANNUITY_CREDIT_RATIO

# %%
# APPS_ANNUITY_CREDIT_RATIO
temp = woeDF_include2[woeDF_include2['Variable'] == 'APPS_ANNUITY_CREDIT_RATIO']
temp
# Out:
#                      Variable            Cutoff      N  Events  % of Events  \
# 0   APPS_ANNUITY_CREDIT_RATIO  (0.0211, 0.0294]  31073  1836.0     0.073958
# 1   APPS_ANNUITY_CREDIT_RATIO  (0.0294, 0.0332]  30463  2158.0     0.086928
# 2   APPS_ANNUITY_CREDIT_RATIO  (0.0332, 0.0397]  31107  2265.0     0.091239
# 3   APPS_ANNUITY_CREDIT_RATIO  (0.0397, 0.0454]  30361  1533.0     0.061752
# 4   APPS_ANNUITY_CREDIT_RATIO    (0.0454, 0.05]  56626  5513.0     0.222075
# 5   APPS_ANNUITY_CREDIT_RATIO    (0.05, 0.0512]   5133   466.0     0.018771
# 6   APPS_ANNUITY_CREDIT_RATIO  (0.0512, 0.0563]  30493  3012.0     0.121329
# 7   APPS_ANNUITY_CREDIT_RATIO  (0.0563, 0.0684]  30745  3077.0     0.123948
# 8   APPS_ANNUITY_CREDIT_RATIO  (0.0684, 0.0951]  30758  3478.0     0.140101
# 9   APPS_ANNUITY_CREDIT_RATIO   (0.0951, 0.124]  30740  1487.0     0.059899
# 10  APPS_ANNUITY_CREDIT_RATIO           Missing     12     0.0     0.000020
#
#     Non-Events  % of Non-Events       WoE        IV
# 0      29237.0         0.103426 -0.335360  0.009882
# 1      28305.0         0.100129 -0.141371  0.001866
# 2      28842.0         0.102028 -0.111772  0.001206
# 3      28828.0         0.101979 -0.501635  0.020179
# 4      51113.0         0.180812  0.205556  0.008482
# 5       4667.0         0.016509  0.128399  0.000290
# 6      27481.0         0.097214  0.221595  0.005344
# 7      27668.0         0.097875  0.236164  0.006157
# 8      27280.0         0.096503  0.372789  0.016253
# 9      29253.0         0.103482 -0.546736  0.023828
# 10        12.0         0.000042 -0.745568  0.000017

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## DAYS_BIRTH

# %%
# DAYS_BIRTH
temp = woeDF_include2[woeDF_include2['Variable'] == 'DAYS_BIRTH']
temp
# Out:
#      Variable                  Cutoff      N  Events  % of Events  Non-Events  \
# 0  DAYS_BIRTH  (-25229.001, -22181.0]  30757  1508.0     0.060745     29249.0
# 1  DAYS_BIRTH    (-22181.0, -20474.0]  30756  1668.0     0.067190     29088.0
# 2  DAYS_BIRTH    (-20474.0, -18885.0]  30757  1950.0     0.078550     28807.0
# 3  DAYS_BIRTH    (-18885.0, -17220.0]  30741  2194.0     0.088379     28547.0
# 4  DAYS_BIRTH    (-17220.0, -15750.0]  30761  2397.0     0.096556     28364.0
# 5  DAYS_BIRTH    (-15750.0, -14416.0]  30756  2434.0     0.098046     28322.0
# 6  DAYS_BIRTH    (-14416.0, -13140.0]  30740  2721.0     0.109607     28019.0
# 7  DAYS_BIRTH    (-13140.0, -11694.0]  30755  3015.0     0.121450     27740.0
# 8  DAYS_BIRTH    (-11694.0, -10284.0]  30764  3380.0     0.136153     27384.0
# 9  DAYS_BIRTH     (-10284.0, -7489.0]  30724  3558.0     0.143323     27166.0
#
#    % of Non-Events       WoE        IV
# 0         0.103468 -0.532576  0.022753
# 1         0.102899 -0.426215  0.015219
# 2         0.101905 -0.260304  0.006079
# 3         0.100985 -0.133340  0.001681
# 4         0.100337 -0.038417  0.000145
# 5         0.100189 -0.021617  0.000046
# 6         0.099117  0.100602  0.001055
# 7         0.098130  0.213210  0.004972
# 8         0.096871  0.340402  0.013372
# 9         0.096100  0.399718  0.018876

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## CARD_M3BALANCE_LIMIT_RATIO_MAX

# %%
# CARD_M3BALANCE_LIMIT_RATIO_MAX
temp = woeDF_include2[woeDF_include2['Variable'] == 'CARD_M3BALANCE_LIMIT_RATIO_MAX']
temp
# Out:
#                          Variable           Cutoff       N   Events  \
# 0  CARD_M3BALANCE_LIMIT_RATIO_MAX  (-0.001, 0.466]   39395   2240.0
# 1  CARD_M3BALANCE_LIMIT_RATIO_MAX    (0.466, 0.89]    6565    518.0
# 2  CARD_M3BALANCE_LIMIT_RATIO_MAX    (0.89, 0.989]    6566    841.0
# 3  CARD_M3BALANCE_LIMIT_RATIO_MAX   (0.989, 1.035]    6566   1050.0
# 4  CARD_M3BALANCE_LIMIT_RATIO_MAX     (1.035, inf]    6566   1362.0
# 5  CARD_M3BALANCE_LIMIT_RATIO_MAX          Missing  241853  18814.0
#
#    % of Events  Non-Events  % of Non-Events       WoE        IV
# 0     0.090232     37155.0         0.131436 -0.376137  0.015498
# 1     0.020866      6047.0         0.021391 -0.024857  0.000013
# 2     0.033877      5725.0         0.020252  0.514479  0.007010
# 3     0.042296      5516.0         0.019513  0.773623  0.017626
# 4     0.054864      5204.0         0.018409  1.092012  0.039809
# 5     0.757865    223039.0         0.788999 -0.040260  0.001253

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## INS_D365SK_DPD_MAX

# %%
# INS_D365SK_DPD_MAX
temp = woeDF_include2[woeDF_include2['Variable'] == 'INS_D365SK_DPD_MAX']
temp
# Out:
#              Variable             Cutoff      N  Events  % of Events  \
# 0  INS_D365SK_DPD_MAX  (-325.001, -12.0]  22071  1336.0     0.053817
# 1  INS_D365SK_DPD_MAX      (-12.0, -8.0]  22169  1333.0     0.053696
# 2  INS_D365SK_DPD_MAX       (-8.0, -4.0]  26036  1662.0     0.066949
# 3  INS_D365SK_DPD_MAX       (-4.0, -2.0]  18219  1197.0     0.048218
# 4  INS_D365SK_DPD_MAX        (-2.0, 0.0]  64411  4628.0     0.186425
# 5  INS_D365SK_DPD_MAX         (0.0, 2.0]  22130  2091.0     0.084230
# 6  INS_D365SK_DPD_MAX         (2.0, 5.0]  19602  2139.0     0.086163
# 7  INS_D365SK_DPD_MAX      (5.0, 2884.0]  21235  3225.0     0.129909
# 8  INS_D365SK_DPD_MAX            Missing  91638  7214.0     0.290594
#
#    Non-Events  % of Non-Events       WoE        IV
# 0     20735.0         0.073350 -0.309657  0.006049
# 1     20836.0         0.073707 -0.316765  0.006339
# 2     24374.0         0.086223 -0.253010  0.004877
# 3     17022.0         0.060215 -0.222203  0.002666
# 4     59783.0         0.211482 -0.126111  0.003160
# 5     20039.0         0.070888  0.172448  0.002301
# 6     17463.0         0.061775  0.332740  0.008115
# 7     18010.0         0.063710  0.712491  0.047166
# 8     84424.0         0.298649 -0.027343  0.000220

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## APPS_GOODS_CREDIT_RATIO

# %%
# APPS_INCOME_EMPLOYED_RATIO
temp = woeDF_include2[woeDF_include2['Variable'] == 'APPS_GOODS_CREDIT_RATIO']
temp
# Out:
#                   Variable          Cutoff       N  Events  % of Events  \
# 0  APPS_GOODS_CREDIT_RATIO  (0.166, 0.783]   31047  3895.0     0.156898
# 1  APPS_GOODS_CREDIT_RATIO  (0.783, 0.826]   31619  3474.0     0.139940
# 2  APPS_GOODS_CREDIT_RATIO  (0.826, 0.856]   29504  2666.0     0.107392
# 3  APPS_GOODS_CREDIT_RATIO  (0.856, 0.873]   32162  2735.0     0.110171
# 4  APPS_GOODS_CREDIT_RATIO  (0.873, 0.894]   33279  2214.0     0.089184
# 5  APPS_GOODS_CREDIT_RATIO  (0.894, 0.927]   26948  1821.0     0.073353
# 6  APPS_GOODS_CREDIT_RATIO    (0.927, 1.0]  122414  7986.0     0.321692
# 7  APPS_GOODS_CREDIT_RATIO    (1.0, 6.667]     260    13.0     0.000524
# 8  APPS_GOODS_CREDIT_RATIO         Missing     278    21.0     0.000846
#
#    Non-Events  % of Non-Events       WoE        IV
# 0     27152.0         0.096050  0.490729  0.029860
# 1     28145.0         0.099563  0.340422  0.013745
# 2     26838.0         0.094939  0.123246  0.001535
# 3     29427.0         0.104098  0.056704  0.000344
# 4     31065.0         0.109892 -0.208795  0.004324
# 5     25127.0         0.088887 -0.192072  0.002983
# 6    114428.0         0.404788 -0.229770  0.019093
# 7       247.0         0.000874 -0.511953  0.000179
# 8       257.0         0.000909 -0.072068  0.000005

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## PREV_REFUSED_RATIO

# %%
# PREV_REFUSED_RATIO
temp = woeDF_include2[woeDF_include2['Variable'] == 'PREV_REFUSED_RATIO']
temp
# Out:
#              Variable           Cutoff       N   Events  % of Events  \
# 0  PREV_REFUSED_RATIO  (-0.001, 0.143]  206507  14639.0     0.589688
# 1  PREV_REFUSED_RATIO    (0.143, 0.25]   31260   2679.0     0.107915
# 2  PREV_REFUSED_RATIO      (0.25, 0.4]   26320   2797.0     0.112669
# 3  PREV_REFUSED_RATIO       (0.4, 1.0]   26577   3709.0     0.149406
# 4  PREV_REFUSED_RATIO          Missing   16847   1001.0     0.040322
#
#    Non-Events  % of Non-Events       WoE        IV
# 0    191868.0         0.678732 -0.140633  0.012523
# 1     28581.0         0.101105  0.065187  0.000444
# 2     23523.0         0.083212  0.303054  0.008927
# 3     22868.0         0.080895  0.613509  0.042032
# 4     15846.0         0.056055 -0.329432  0.005183

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## INS_INS_IS_DPD_UNDER_120_MEAN

# %%
# INS_INS_IS_DPD_UNDER_120_MEAN
temp = woeDF_include2[woeDF_include2['Variable'] == 'INS_INS_IS_DPD_UNDER_120_MEAN']
temp
# Out:
#                         Variable            Cutoff       N  Events  \
# 0  INS_INS_IS_DPD_UNDER_120_MEAN  (-0.001, 0.0175]  145871  9825.0
# 1  INS_INS_IS_DPD_UNDER_120_MEAN  (0.0175, 0.0476]   29688  2160.0
# 2  INS_INS_IS_DPD_UNDER_120_MEAN  (0.0476, 0.0857]   28865  2463.0
# 3  INS_INS_IS_DPD_UNDER_120_MEAN   (0.0857, 0.143]   30222  2952.0
# 4  INS_INS_IS_DPD_UNDER_120_MEAN    (0.143, 0.237]   27927  2802.0
# 5  INS_INS_IS_DPD_UNDER_120_MEAN      (0.237, 1.0]   29070  3674.0
# 6  INS_INS_IS_DPD_UNDER_120_MEAN           Missing   15868   949.0
#
#    % of Events  Non-Events  % of Non-Events       WoE        IV
# 0     0.395770    136046.0         0.481262 -0.195577  0.016720
# 1     0.087009     27528.0         0.097380 -0.112610  0.001168
# 2     0.099215     26402.0         0.093397  0.060426  0.000352
# 3     0.118912     27270.0         0.096467  0.209181  0.004695
# 4     0.112870     25125.0         0.088880  0.238956  0.005733
# 5     0.147996     25396.0         0.089838  0.499175  0.029031
# 6     0.038228     14919.0         0.052776 -0.322497  0.004692

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## INS_D365AMT_RATIO_MEAN

# %%
# NAME_INCOME_TYPE
temp = woeDF_include2[woeDF_include2['Variable'] == 'INS_D365AMT_RATIO_MEAN']
temp
# Out:
#                  Variable                         Cutoff       N   Events  \
# 0  INS_D365AMT_RATIO_MEAN  (-0.0009214000000000001, 0.9]   21594   2867.0
# 1  INS_D365AMT_RATIO_MEAN                   (0.9, 0.997]   21581   2523.0
# 2  INS_D365AMT_RATIO_MEAN                   (0.997, 1.0]  152119  11028.0
# 3  INS_D365AMT_RATIO_MEAN                  (1.0, 3376.3]   20579   1193.0
# 4  INS_D365AMT_RATIO_MEAN                        Missing   91638   7214.0
#
#    % of Events  Non-Events  % of Non-Events       WoE        IV
# 0     0.115488     18727.0         0.066247  0.555785  0.027368
# 1     0.101631     19058.0         0.067418  0.410447  0.014043
# 2     0.444230    141091.0         0.499109 -0.116482  0.006392
# 3     0.048056     19386.0         0.068578 -0.355594  0.007297
# 4     0.290594     84424.0         0.298649 -0.027343  0.000220

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## REGION_RATING_CLIENT_W_CITY

# %%
train['REGION_RATING_CLIENT_W_CITY'].value_counts()
# Out:
# 2    156125
# 3     29691
# 1     23291
# Name: REGION_RATING_CLIENT_W_CITY, dtype: int64

# %%
# PREV_D365_PREV_INTERESTS_RATE_MAX
temp = woeDF_include2[woeDF_include2['Variable'] == 'REGION_RATING_CLIENT_W_CITY']
temp
# Out:
#                       Variable Cutoff       N   Events  % of Events  \
# 0  REGION_RATING_CLIENT_W_CITY      1   34167   1654.0     0.066626
# 1  REGION_RATING_CLIENT_W_CITY      2  229484  18170.0     0.731923
# 2  REGION_RATING_CLIENT_W_CITY      3   43860   5001.0     0.201450
#
#    Non-Events  % of Non-Events       WoE        IV
# 0     32513.0         0.115015 -0.545958  0.026418
# 1    211314.0         0.747522 -0.021088  0.000329
# 2     38859.0         0.137463  0.382184  0.024455

# %%
temp['Bin'] = [i for i in range(temp.shape[0])]
temp = temp.rename(columns = {'% of Events': 'GOOD','% of Non-Events': 'BAD'})
ax = temp[['Bin', 'WoE']].plot(x = 'Bin', kind = 'line', 
                                              secondary_y=True, color = 'green')
ax = temp[['GOOD', 'BAD', 'Bin']].set_index('Bin').plot.bar(stacked=True, 
                                                                         ax = ax)
# plt.xticks(rotation = 30)
plt.show()
